# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorHugoMartins/israel_x_palestine_data_analysis/blob/main/preprocess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pré-Processamento de Dados
#
# Este arquivo prepara os dados para as fases posteriores.

# %% [markdown]
# # Importação de Dados

# %%
from google.colab import drive
drive.mount('/content/drive')

base_path = '/content/drive/My Drive/Mestrado'

country = 'palestine'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import os

def read_csv_batches_from_dir(directory):
    all_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.csv')]
    df_list = []

    for file in all_files:
        print(f"Lendo arquivo: {file}")
        df = pd.read_csv(file)
        df_list.append(df)

    # Concatenar todos os DataFrames em um só
    final_df = pd.concat(df_list, ignore_index=True)
    return final_df

def import_data(country):
  # Caminho base no Google Drive

  # Diretórios contendo os arquivos CSV de comentários, vídeos e canais
  comments_dir = os.path.join(base_path, '{country}/comments_csv_batches'.format(country=country))
  videos_dir = os.path.join(base_path, '{country}/videos_csv_batches'.format(country=country))
  channels_dir = os.path.join(base_path, '{country}/channels_csv_batches'.format(country=country))

  # Ler todos os arquivos CSV dos diretórios
  df_comments = read_csv_batches_from_dir(comments_dir)
  df_videos = read_csv_batches_from_dir(videos_dir)
  df_channels = read_csv_batches_from_dir(channels_dir)

  return df_comments, df_videos, df_channels

palestine_df_comments, df_videos, df_channels = import_data('palestine')

original_comments = palestine_df_comments
# Out:
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_1.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_4.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_5.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_2.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_3.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_7.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_6.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_8.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_11.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_12.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_9.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_10.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_14.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_15.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_13.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_16.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_19.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_18.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_17.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_21.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_23.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_20.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_22.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_24.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_25.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_26.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_30.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_27.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_29.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_28.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_33.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_31.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_32.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_34.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_36.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_35.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_39.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_38.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_37.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_41.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_42.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_40.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_44.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_45.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_43.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_48.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_46.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_47.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_50.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_49.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_51.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_52.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_53.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_54.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_55.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_56.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_58.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_57.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_59.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_61.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_60.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_64.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_62.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_63.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_66.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_65.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_67.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_68.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_69.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_71.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_72.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_70.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_73.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_74.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_76.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_75.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_77.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_80.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_79.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_78.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_81.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_82.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/videos_csv_batches/lote_1.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/channels_csv_batches/lote_1.csv

# %% [markdown]
# ## Dados Originais

# %% [markdown]
# ### Comments

# %%
palestine_df_comments
# Out:
#            video_id                                         comment_id  \
# 0       rai_sj91Mts  Ugw9jGAzIj7ZEd3ctsJ4AaABAg.A9SXu5XETuNA9_YDq1UL2d
# 1       KnIUzxhDLXQ                         UgzipCDxCGKZdbENemV4AaABAg
# 2       rai_sj91Mts  Ugw9jGAzIj7ZEd3ctsJ4AaABAg.A9SXu5XETuNA9_XoU4LceB
# 3       lYXzMnN7SFg                         UgzQrdFWVWfAQ8zcU3B4AaABAg
# 4       IpA8TU9brro  Ugz3S4TxqoQMvXcJ4aZ4AaABAg.A9WTlNPItFlA9_XLKZ1W5O
# ...             ...                                                ...
# 814970  d8AP7rQvV6Y                         Ugw51FdhTUWk9lGjRTd4AaABAg
# 814971  d8AP7rQvV6Y                         UgwNzQ7P-35_ZPkw-MZ4AaABAg
# 814972  d8AP7rQvV6Y                         UgyFeWKQDfg6KgAOorx4AaABAg
# 814973  d8AP7rQvV6Y                         Ugyi8qwzcz7Ktvg42A94AaABAg
# 814974  d8AP7rQvV6Y                         Ugy6qZn-K_pSYHQOeDR4AaABAg
#
#                      author  \
# 0       @ehitaredestiny3146
# 1               @darwisojol
# 2                 @1nadiald
# 3            @andrysabatini
# 4                @1312Mork2
# ...                     ...
# 814970    @faizahfaizah8255
# 814971    @lukmanjourney641
# 814972           @Saskoloep
# 814973    @faizalarffin2482
# 814974  @HamjahHamjah-zf8ss
#
#                                  author_profile_image_url  \
# 0       https://yt3.ggpht.com/DE8gbtNTtEb2oI-PKjR2Gw6k...
# 1       https://yt3.ggpht.com/ytc/AIdro_njGmxKfoPrBMaI...
# 2       https://yt3.ggpht.com/ytc/AIdro_nAc7gln-BI6Q9p...
# 3       https://yt3.ggpht.com/6x1qe70o20YWrVdsYCEfDWfy...
# 4       https://yt3.ggpht.com/oSPCnt4WtvcVNqVW4Zvcty5q...
# ...                                                   ...
# 814970  https://yt3.ggpht.com/ytc/AIdro_nFJwocGV8DNqOb...
# 814971  https://yt3.ggpht.com/KLiMwgezEoPzLeuspnu2mMm_...
# 814972  https://yt3.ggpht.com/ytc/AIdro_n-ipYGNyWfz12O...
# 814973  https://yt3.ggpht.com/ytc/AIdro_kdKHEaF6TdB4sb...
# 814974  https://yt3.ggpht.com/ytc/AIdro_npcUR6XsdtEyWk...
#
#                                 author_channel_url         author_channel_id  \
# 0       http://www.youtube.com/@ehitaredestiny3146  UCqC4Hff0ccqdyW9bIQzGSXQ
# 1               http://www.youtube.com/@darwisojol  UCSlryZdcLthIgB_uYpTgEUA
# 2                 http://www.youtube.com/@1nadiald  UCQxFdS-yyMmdd5LnXRG-FoQ
# 3            http://www.youtube.com/@andrysabatini  UC-LNuL326djA50s-0PRq1Lw
# 4                http://www.youtube.com/@1312Mork2  UC6VNPUQL3ltQsJ8bUfRswiQ
# ...                                            ...                       ...
# 814970    http://www.youtube.com/@faizahfaizah8255  UC3XRFOdxYT0MHUaINaosDww
# 814971    http://www.youtube.com/@lukmanjourney641  UCn3ZkgKF-r_QYzp8RiLCETQ
# 814972           http://www.youtube.com/@Saskoloep  UCRRCgLlbKDst9fFjEpfRP_A
# 814973    http://www.youtube.com/@faizalarffin2482  UCsgog3YohGNKrJOhD78RpUQ
# 814974  http://www.youtube.com/@HamjahHamjah-zf8ss  UCp_WABcAVHu7-A0UMPktPuQ
#
#                                                   comment  \
# 0       @@1nadiald what a beautiful liar! Maybe y’all ...
# 1                                                  😂😂😂😂😂😂
# 2                                      What a Dumas take!
# 3                           uomo dispensatore di morte...
# 4                    You need to stop doing thought crime
# ...                                                   ...
# 814970           Ber arti udah mulai jatuh alhamdulillah😊
# 814971  Pertanda idf sudah mau punah dihajar hamas mak...
# 814972  Strategi jitu, kalau tidak mau dikembalikan ke...
# 814973  Tak payah lah Nak menipu lagi, lagipun negara ...
# 814974                Jangan ikut bergabung dengan Israel
#
#                 published_at            updated_at  like_count viewer_rating  \
# 0       2024-10-14T15:41:23Z  2024-10-14T15:41:23Z           0          none
# 1       2024-10-14T15:38:25Z  2024-10-14T15:38:25Z           0          none
# 2       2024-10-14T15:37:47Z  2024-10-14T15:37:47Z           0          none
# 3       2024-10-14T15:35:50Z  2024-10-14T15:35:50Z           0          none
# 4       2024-10-14T15:33:40Z  2024-10-14T15:33:40Z           0          none
# ...                      ...                   ...         ...           ...
# 814970  2024-09-17T05:54:33Z  2024-09-17T05:54:33Z         128          none
# 814971  2024-09-17T05:53:14Z  2024-09-17T05:53:14Z         149          none
# 814972  2024-09-17T05:45:38Z  2024-09-17T05:45:38Z          11          none
# 814973  2024-09-17T05:43:54Z  2024-09-17T05:43:54Z           0          none
# 814974  2024-09-17T05:33:00Z  2024-09-17T05:33:00Z           0          none
#
#         can_rate  is_reply                   parent_id  \
# 0           True      True  Ugw9jGAzIj7ZEd3ctsJ4AaABAg
# 1           True     False                         NaN
# 2           True      True  Ugw9jGAzIj7ZEd3ctsJ4AaABAg
# 3           True     False                         NaN
# 4           True      True  Ugz3S4TxqoQMvXcJ4aZ4AaABAg
# ...          ...       ...                         ...
# 814970      True     False                         NaN
# 814971      True     False                         NaN
# 814972      True     False                         NaN
# 814973      True     False                         NaN
# 814974      True     False                         NaN
#
#                       channel_id
# 0       UCatt7TBjfBkiJWx8khav_Gg
# 1       UC7fWeaHhqgM4Ry-RMpM2YYw
# 2       UCatt7TBjfBkiJWx8khav_Gg
# 3       UCef1-8eOpJgud7szVPlZQAQ
# 4       UCckHqySbfy5FcPP6MD_S-Yg
# ...                          ...
# 814970  UCmxAIW7RDDC88EPk4ry16Kg
# 814971  UCmxAIW7RDDC88EPk4ry16Kg
# 814972  UCmxAIW7RDDC88EPk4ry16Kg
# 814973  UCmxAIW7RDDC88EPk4ry16Kg
# 814974  UCmxAIW7RDDC88EPk4ry16Kg
#
# [814975 rows x 15 columns]

# %%
palestine_df_comments.describe()
# Out:
#           like_count
# count  814975.000000
# mean        6.592394
# std        95.218460
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max     23049.000000

# %% [markdown]
# ### Vídeos

# %%
df_videos
# Out:
#         video_id                                              title  \
# 0    Q_7QIgSANlg  Israeli strike in Aitou in northern Lebanon ki...
# 1    bEzEBz7d1Z8  Israel Vs Hezbollah War LIVE | Inside Israel's...
# 2    tmDjav-5dUI  Israeli air strike destroys historic mosque in...
# 3    NOLJdq4zWFs  Israeli shelling of Gaza school kills at least...
# 4    gTP3ug1DBs0  Israel's brutality towards Palestinians didn’t...
# ..           ...                                                ...
# 806  rGgnRV_Hvw0  ‘Lawless world’ faced by Palestinians in the W...
# 807  a64qJkg2Ac4  Hypersonic Missile Hits Israel | US and Israel...
# 808  oVR7mgvISiA  Gaza Offensive: Israel Recruiting Asylum Seeke...
# 809  N45Kdm-Ue-U  Iran’s 3-Way Proxy War Crushes IDF; Israel Scr...
# 810  rvlQIo60tV4  IDF Shamed By Freed Hostages About Rescue Ops,...
#
#                                            description  \
# 0    The Lebanese Red Cross said 18 people were kil...
# 1    Israel Vs Hezbollah War LIVE | Inside Israel's...
# 2    Israel has destroyed an old mosque in southern...
# 3    An Israeli attack on a school used to shelter ...
# 4    The brutality Israel has been unleashing on Pa...
# ..                                                 ...
# 806  “The fact that I have an Israeli passport and ...
# 807  #Israel #Yemen #Missile #PrashantDhawan #Prash...
# 808  Israel is recruiting African asylum seekers to...
# 809  A fresh report by Israeli media outlet Haaretz...
# 810  Freed Israeli captives spill beans months afte...
#
#                    channel_id          published_at  category_id  \
# 0    UC16niRr50-MSBwiO3YDb3RA  2024-10-14T15:43:19Z           25
# 1    UCef1-8eOpJgud7szVPlZQAQ  2024-10-14T15:34:53Z           25
# 2    UCR0fZh5SBxxMNYdg0VzRFkg  2024-10-14T14:38:56Z           25
# 3    UC16niRr50-MSBwiO3YDb3RA  2024-10-14T14:34:39Z           25
# 4    UC7fWeaHhqgM4Ry-RMpM2YYw  2024-10-14T13:54:43Z           25
# ..                        ...                   ...          ...
# 806  UCR0fZh5SBxxMNYdg0VzRFkg  2024-09-15T14:32:18Z           25
# 807  UCrC8mOqJQpoB7NuIMKIS6rQ  2024-09-15T14:28:00Z           27
# 808  UC_xWTNsx7zA2uI0ydQikViA  2024-09-15T13:40:01Z           25
# 809  UCckHqySbfy5FcPP6MD_S-Yg  2024-09-15T12:10:00Z           25
# 810  UCm7lHFkt2yB_WzL67aruVBQ  2024-09-15T04:56:08Z           25
#
#                                                   tags  view_count  \
# 0    ['bbc', 'bbc news', 'news', 'world news', 'bre...        7860
# 1    ['Israel Vs Hezbollah War', 'Israel Lebanon Wa...        9347
# 2    ['middle east eye', 'mee', 'mee news', 'news',...        7805
# 3    ['bbc', 'bbc news', 'news', 'world news', 'bre...        7076
# 4    ['TRT world', 'trtworld', 'World News', 'break...        3866
# ..                                                 ...         ...
# 806  ['middle east eye', 'mee', 'mee news', 'news',...        7690
# 807  ['Gaza', 'Hamas', 'Houthi attacks on israel', ...     1871962
# 808  ['dawn news english', 'dawn news', 'dawn news ...        1003
# 809  ['times of india', 'toi', 'latest news', 'news...       21121
# 810  ['hindustan times', 'ht media', 'ht news', 'hi...      127810
#
#      like_count  comment_count  ... scheduled_end_time concurrent_viewers  \
# 0           158            113  ...                NaN                  0
# 1            66              3  ...                NaN                  0
# 2          1179            342  ...                NaN                  0
# 3           364            174  ...                NaN                  0
# 4          1391             49  ...                NaN                  0
# ..          ...            ...  ...                ...                ...
# 806         809             73  ...                NaN                  0
# 807       58048           4592  ...                NaN                  0
# 808          19              5  ...                NaN                  0
# 809         281            163  ...                NaN                  0
# 810        2320            745  ...                NaN                  0
#
#      active_live_chat_id  recording_date  \
# 0                    NaN             NaN
# 1                    NaN             NaN
# 2                    NaN             NaN
# 3                    NaN             NaN
# 4                    NaN             NaN
# ..                   ...             ...
# 806                  NaN             NaN
# 807                  NaN             NaN
# 808                  NaN             NaN
# 809                  NaN             NaN
# 810                  NaN             NaN
#
#                                        topicCategories processing_status  \
# 0    ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# 1    ['https://en.wikipedia.org/wiki/Military', 'ht...               NaN
# 2            ['https://en.wikipedia.org/wiki/Society']               NaN
# 3    ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# 4    ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# ..                                                 ...               ...
# 806  ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# 807          ['https://en.wikipedia.org/wiki/Society']               NaN
# 808          ['https://en.wikipedia.org/wiki/Society']               NaN
# 809  ['https://en.wikipedia.org/wiki/Military', 'ht...               NaN
# 810  ['https://en.wikipedia.org/wiki/Military', 'ht...               NaN
#
#      parts_total  parts_processed  time_left_ms processing_failure_reason
# 0              0                0             0                       NaN
# 1              0                0             0                       NaN
# 2              0                0             0                       NaN
# 3              0                0             0                       NaN
# 4              0                0             0                       NaN
# ..           ...              ...           ...                       ...
# 806            0                0             0                       NaN
# 807            0                0             0                       NaN
# 808            0                0             0                       NaN
# 809            0                0             0                       NaN
# 810            0                0             0                       NaN
#
# [811 rows x 35 columns]

# %%
df_videos.describe()
# Out:
#        category_id    view_count     like_count  comment_count  \
# count   811.000000  8.110000e+02     811.000000     811.000000
# mean     24.890259  2.160685e+05    5351.081381    1025.027127
# std       1.803711  4.705475e+05   14116.863401    2457.954095
# min       1.000000  4.000000e+00       0.000000       1.000000
# 25%      25.000000  1.997750e+04     448.500000      99.000000
# 50%      25.000000  6.583500e+04    1563.000000     377.000000
# 75%      25.000000  2.194575e+05    4485.500000    1095.500000
# max      29.000000  6.836883e+06  216578.000000   35712.000000
#
#        scheduled_end_time  concurrent_viewers  active_live_chat_id  \
# count                 0.0               811.0                  0.0
# mean                  NaN                 0.0                  NaN
# std                   NaN                 0.0                  NaN
# min                   NaN                 0.0                  NaN
# 25%                   NaN                 0.0                  NaN
# 50%                   NaN                 0.0                  NaN
# 75%                   NaN                 0.0                  NaN
# max                   NaN                 0.0                  NaN
#
#        processing_status  parts_total  parts_processed  time_left_ms  \
# count                0.0        811.0            811.0         811.0
# mean                 NaN          0.0              0.0           0.0
# std                  NaN          0.0              0.0           0.0
# min                  NaN          0.0              0.0           0.0
# 25%                  NaN          0.0              0.0           0.0
# 50%                  NaN          0.0              0.0           0.0
# 75%                  NaN          0.0              0.0           0.0
# max                  NaN          0.0              0.0           0.0
#
#        processing_failure_reason
# count                        0.0
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN

# %% [markdown]
# ### Canais

# %%
df_channels
# Out:
#                    channel_id                                     title  \
# 0    UC3asD3ORk07XRPGC47hr-0w                              GNC NEWS 360
# 1    UCkmLoDQ8AVKwEsDSJtNKmug                                 WOLD NEWS
# 2    UC1Dlsbku0-iCGc0rXgQpDHQ                            Amaizing Facts
# 3    UC3-n3-ScTQLQ_Gc2tNLJreg  Stakelbeck Tonight with Erick Stakelbeck
# 4    UCF9LFWX5cdGHBg_FDm6tFrQ                           Breezy Politics
# ..                        ...                                       ...
# 216  UCfmSignFWkk1lw4015hCyyQ                               StandWithUs
# 217  UC16niRr50-MSBwiO3YDb3RA                                  BBC News
# 218  UCHpw8xwDNhU9gdohEcJu4aA                              The Guardian
# 219  UCm7lHFkt2yB_WzL67aruVBQ                           Hindustan Times
# 220  UCupvZG-5ko_eiXAupbDfxWw                                       CNN
#
#                                            description  \
# 0    🌍 Welcome to GNC – Global News Channel! 🌍\n\nA...
# 1                                   Subscribe  for USA
# 2    Target Subscribers 1 Million\n\nHello everyone...
# 3    Welcome to the Stakelbeck Tonight with Erick S...
# 4                             Politics By The People.
# ..                                                 ...
# 216  Fighting Antisemitism and Supporting Israel Ar...
# 217  Welcome to the official BBC News YouTube chann...
# 218  The Guardian brings you news, documentaries, a...
# 219  Hindustan Times Videos bring you news, views a...
# 220  CNN is the world leader in news and informatio...
#
#                     published_at country   view_count  comment_count  \
# 0    2024-09-22T02:57:31.675741Z      US         7096              0
# 1    2024-08-31T21:48:41.363607Z      US       372583              0
# 2    2024-06-05T10:37:49.325123Z      PK     84711317              0
# 3    2024-05-03T21:23:42.240192Z      US      2423653              0
# 4    2024-02-24T18:00:09.134775Z      US    101447822              0
# ..                           ...     ...          ...            ...
# 216         2006-06-06T22:44:08Z      IL     44427727              0
# 217         2006-04-08T05:51:05Z      GB   5607586404              0
# 218         2006-02-15T03:22:40Z      GB    729761411              0
# 219         2005-11-16T02:41:16Z      IN   5607879981              0
# 220         2005-10-02T16:06:36Z     NaN  16751878276              0
#
#      subscriber_count  video_count  is_verified  \
# 0                  27           20        False
# 1                 481          275        False
# 2              238000          412        False
# 3               31300           70        False
# 4              206000          575        False
# ..                ...          ...          ...
# 216            192000         1465        False
# 217          16800000        23220        False
# 218           2290000         7250        False
# 219           7370000        69366        False
# 220          17100000       167408        False
#
#                                               keywords  \
# 0                                                  NaN
# 1                  trump noticia "kamalla harris" vote
# 2    short shorts animals viral edits israel palest...
# 3    "erick stakelbeck" "the watchman with erick st...
# 4                                                  NaN
# ..                                                 ...
# 216  standwithus Israel Education activism pro-isra...
# 217                  BBC News Official YouTube Channel
# 218  guardian news film video environment documenta...
# 219  "world news" "us news" "HT world" "Hindustan T...
# 220                CNN "CNN News" news "breaking news"
#
#                                    profile_picture_url
# 0    https://yt3.ggpht.com/rE7KFfBo-a7KVXDR2xtVoESi...
# 1    https://yt3.ggpht.com/VZXxIUrbv9NoSwomQz_4sOlC...
# 2    https://yt3.ggpht.com/dCjKkhHRFEPvorpV1vhdD1XT...
# 3    https://yt3.ggpht.com/Oz0YlzbQAiPwkqA0vH1832AL...
# 4    https://yt3.ggpht.com/I5YmN4cKN0Vaon04Qs9hBbF2...
# ..                                                 ...
# 216  https://yt3.ggpht.com/ytc/AIdro_mh8eN8fDlZehoy...
# 217  https://yt3.ggpht.com/y_esGAQOhX4rTpWvrALErAJl...
# 218  https://yt3.ggpht.com/P7QrZEnioCzOeKA2sWKyxvR5...
# 219  https://yt3.ggpht.com/rxxycwwjFXuC-eQNBcklj4P-...
# 220  https://yt3.ggpht.com/n5DRh94eycw6xGcOKTn6LKQw...
#
# [221 rows x 12 columns]

# %%
df_channels.describe()
# Out:
#          view_count  comment_count  subscriber_count    video_count
# count  2.210000e+02          221.0      2.210000e+02     221.000000
# mean   1.493047e+09            0.0      2.641411e+06   36474.914027
# std    2.928207e+09            0.0      3.996751e+06   72141.218975
# min    7.096000e+03            0.0      2.700000e+01      20.000000
# 25%    2.814296e+07            0.0      1.520000e+05     711.000000
# 50%    2.711304e+08            0.0      9.650000e+05    3043.000000
# 75%    1.490802e+09            0.0      3.570000e+06   37819.000000
# max    1.812601e+10            0.0      2.210000e+07  610000.000000

# %% [markdown]
# # Limpeza de Comentários
#
# Redução do vocabulário dos comentários coletados. Vídeos e Canais não passam por esse processo por não serem o foco da pesquisa e servirem como bases auxiliares para o percurso principal.

# %% [markdown]
# ## Remoção de Dados Duplicados

# %%
# Função para remover duplicatas e manter os registros mais recentes.
# Intuito: garantir que não foram coletados dados repetidos para diferentes países
def remove_duplicates(df, id_column, date_column):
    # Ordena por data de forma decrescente e remove duplicatas mantendo o mais recente
    df_sorted = df.sort_values(by=date_column, ascending=False)
    df_unique = df_sorted.drop_duplicates(subset=id_column, keep='first')
    return df_unique

# %%
# Gerar as estatísticas
palestine_df_comments = remove_duplicates(palestine_df_comments, 'comment_id', 'updated_at')

# %% [markdown]
# ## Filtragem por idioma
#
# Apenas comentários em inglês serão utilizados na pesquisa. Não haverá, por agora, uma abordagem multilanguage.

# %%
# 1. Instalar FastText
# !pip install fasttext

# 2. Importar bibliotecas necessárias
import fasttext
import pandas as pd

# 3. Baixar o modelo de identificação de idiomas do FastText
# Use the raw file URL to download the binary model directly
# !wget https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.bin -O lid.176.bin
# Out:
# Requirement already satisfied: fasttext in /usr/local/lib/python3.10/dist-packages (0.9.3)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.10/dist-packages (from fasttext) (2.13.6)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (75.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.26.4)
# --2024-11-05 17:23:15--  https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.bin
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.35.7.128, 13.35.7.38, 13.35.7.50, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.35.7.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 131266198 (125M) [application/octet-stream]
# Saving to: ‘lid.176.bin’
#
# lid.176.bin         100%[===================>] 125.18M  68.2MB/s    in 1.8s
#
# 2024-11-05 17:23:16 (68.2 MB/s) - ‘lid.176.bin’ saved [131266198/131266198]

# %%
# Carregae o modelo de linguagem
def load_model():
    model_path = 'lid.176.bin'
    model = fasttext.load_model(model_path)
    return model

model = load_model()

# Função para identificar o idioma de um comentário
def detect_language(comment):
    # Remover quebras de linha
    if isinstance(comment, str):
      comment = comment.replace('\n', ' ').strip()  # Remove quebras de linha e espaços extras
      prediction = model.predict(comment)
      return prediction[0][0]  # Retornar o código do idioma
    else:
      return ''

def filter_by_english(df_comments, verbose=False):
  # Aplicar a função de detecção de idioma a cada comentário
  df_comments['language'] = df_comments['comment'].apply(detect_language)

  # Filtrar os comentários em inglês
  english_comments = df_comments[df_comments['language'] == '__label__en']

  if verbose:
    print(english_comments[['comment_id', 'comment']])

  return english_comments

# %%
palestine_df_comments = filter_by_english(palestine_df_comments, verbose=True)
# Out:
#                                                comment_id  \
# 789472                         UgyDIMGydtCmgB41-SN4AaABAg
# 789473                         UgxUGpdHzAceyYbIWDN4AaABAg
# 789474                         UgyPfhLChrSMH0hSopR4AaABAg
# 789475                         UgzcyIzP8x-MpOea_7V4AaABAg
# 759573  UgxUNu91s5_4wWdEJ4h4AaABAg.A8xFzWWQ0MSAAGvsgmW2l1
# ...                                                   ...
# 689599                         UgzaDFIViC98wmEqEdR4AaABAg
# 689600                         Ugw2Jtx0n6qufNR4zQJ4AaABAg
# 689601                         UgyHaEtt528FzLJe_6J4AaABAg
# 689602                         UgzrRIcuLYaO8BfdeM54AaABAg
# 689603                         UgxLKgbvmmwQxoNj3WF4AaABAg
#
#                                                   comment
# 789472  it is said that the 1948 UN resolution justifi...
# 789473  🛑the cease fire deal‼️Lebanon🟰Iran,, Syria🟰Rus...
# 789474                        As they say, “do the math!”
# 789475        Nice try B****. Palestine is a stolen land.
# 759573  @@Akna-mm5di why?just because he is telling th...
# ...                                                   ...
# 689599                    Oops. These is bad news for idf
# 689600  If you repeat a lie often enough, eventually b...
# 689601              Fools are making fool of themselves.😂
# 689602  What is the lie told by the IDF about tunnels ...
# 689603  Ohh No you mean the IDF and the Israeli govern...
#
# [727246 rows x 2 columns]

# %% [markdown]
# ### Filtragem de Vídeos e Canais
#
# Aqui, calculamos o nosso universo a quantidade de canais, vídeos e comentários em inglês. Suas novas quantidades são calculadas, assim como o número de usuários comentaristas.

# %%
# Filtrar vídeos que possuem channel_id em df_channels e video_id em df_comments
df_videos = df_videos[
    (df_videos['video_id'].isin(palestine_df_comments['video_id']))
]

df_videos
# Out:
#         video_id                                              title  \
# 0    Q_7QIgSANlg  Israeli strike in Aitou in northern Lebanon ki...
# 1    bEzEBz7d1Z8  Israel Vs Hezbollah War LIVE | Inside Israel's...
# 2    tmDjav-5dUI  Israeli air strike destroys historic mosque in...
# 3    NOLJdq4zWFs  Israeli shelling of Gaza school kills at least...
# 4    gTP3ug1DBs0  Israel's brutality towards Palestinians didn’t...
# ..           ...                                                ...
# 806  rGgnRV_Hvw0  ‘Lawless world’ faced by Palestinians in the W...
# 807  a64qJkg2Ac4  Hypersonic Missile Hits Israel | US and Israel...
# 808  oVR7mgvISiA  Gaza Offensive: Israel Recruiting Asylum Seeke...
# 809  N45Kdm-Ue-U  Iran’s 3-Way Proxy War Crushes IDF; Israel Scr...
# 810  rvlQIo60tV4  IDF Shamed By Freed Hostages About Rescue Ops,...
#
#                                            description  \
# 0    The Lebanese Red Cross said 18 people were kil...
# 1    Israel Vs Hezbollah War LIVE | Inside Israel's...
# 2    Israel has destroyed an old mosque in southern...
# 3    An Israeli attack on a school used to shelter ...
# 4    The brutality Israel has been unleashing on Pa...
# ..                                                 ...
# 806  “The fact that I have an Israeli passport and ...
# 807  #Israel #Yemen #Missile #PrashantDhawan #Prash...
# 808  Israel is recruiting African asylum seekers to...
# 809  A fresh report by Israeli media outlet Haaretz...
# 810  Freed Israeli captives spill beans months afte...
#
#                    channel_id          published_at  category_id  \
# 0    UC16niRr50-MSBwiO3YDb3RA  2024-10-14T15:43:19Z           25
# 1    UCef1-8eOpJgud7szVPlZQAQ  2024-10-14T15:34:53Z           25
# 2    UCR0fZh5SBxxMNYdg0VzRFkg  2024-10-14T14:38:56Z           25
# 3    UC16niRr50-MSBwiO3YDb3RA  2024-10-14T14:34:39Z           25
# 4    UC7fWeaHhqgM4Ry-RMpM2YYw  2024-10-14T13:54:43Z           25
# ..                        ...                   ...          ...
# 806  UCR0fZh5SBxxMNYdg0VzRFkg  2024-09-15T14:32:18Z           25
# 807  UCrC8mOqJQpoB7NuIMKIS6rQ  2024-09-15T14:28:00Z           27
# 808  UC_xWTNsx7zA2uI0ydQikViA  2024-09-15T13:40:01Z           25
# 809  UCckHqySbfy5FcPP6MD_S-Yg  2024-09-15T12:10:00Z           25
# 810  UCm7lHFkt2yB_WzL67aruVBQ  2024-09-15T04:56:08Z           25
#
#                                                   tags  view_count  \
# 0    ['bbc', 'bbc news', 'news', 'world news', 'bre...        7860
# 1    ['Israel Vs Hezbollah War', 'Israel Lebanon Wa...        9347
# 2    ['middle east eye', 'mee', 'mee news', 'news',...        7805
# 3    ['bbc', 'bbc news', 'news', 'world news', 'bre...        7076
# 4    ['TRT world', 'trtworld', 'World News', 'break...        3866
# ..                                                 ...         ...
# 806  ['middle east eye', 'mee', 'mee news', 'news',...        7690
# 807  ['Gaza', 'Hamas', 'Houthi attacks on israel', ...     1871962
# 808  ['dawn news english', 'dawn news', 'dawn news ...        1003
# 809  ['times of india', 'toi', 'latest news', 'news...       21121
# 810  ['hindustan times', 'ht media', 'ht news', 'hi...      127810
#
#      like_count  comment_count  ... scheduled_end_time concurrent_viewers  \
# 0           158            113  ...                NaN                  0
# 1            66              3  ...                NaN                  0
# 2          1179            342  ...                NaN                  0
# 3           364            174  ...                NaN                  0
# 4          1391             49  ...                NaN                  0
# ..          ...            ...  ...                ...                ...
# 806         809             73  ...                NaN                  0
# 807       58048           4592  ...                NaN                  0
# 808          19              5  ...                NaN                  0
# 809         281            163  ...                NaN                  0
# 810        2320            745  ...                NaN                  0
#
#      active_live_chat_id  recording_date  \
# 0                    NaN             NaN
# 1                    NaN             NaN
# 2                    NaN             NaN
# 3                    NaN             NaN
# 4                    NaN             NaN
# ..                   ...             ...
# 806                  NaN             NaN
# 807                  NaN             NaN
# 808                  NaN             NaN
# 809                  NaN             NaN
# 810                  NaN             NaN
#
#                                        topicCategories processing_status  \
# 0    ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# 1    ['https://en.wikipedia.org/wiki/Military', 'ht...               NaN
# 2            ['https://en.wikipedia.org/wiki/Society']               NaN
# 3    ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# 4    ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# ..                                                 ...               ...
# 806  ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# 807          ['https://en.wikipedia.org/wiki/Society']               NaN
# 808          ['https://en.wikipedia.org/wiki/Society']               NaN
# 809  ['https://en.wikipedia.org/wiki/Military', 'ht...               NaN
# 810  ['https://en.wikipedia.org/wiki/Military', 'ht...               NaN
#
#      parts_total  parts_processed  time_left_ms processing_failure_reason
# 0              0                0             0                       NaN
# 1              0                0             0                       NaN
# 2              0                0             0                       NaN
# 3              0                0             0                       NaN
# 4              0                0             0                       NaN
# ..           ...              ...           ...                       ...
# 806            0                0             0                       NaN
# 807            0                0             0                       NaN
# 808            0                0             0                       NaN
# 809            0                0             0                       NaN
# 810            0                0             0                       NaN
#
# [806 rows x 35 columns]

# %%
df_channels = df_channels[
    (df_channels['channel_id'].isin(palestine_df_comments['channel_id'])) |
    (df_channels['channel_id'].isin(palestine_df_comments['author_channel_id']))
]

df_channels
# Out:
#                    channel_id                                     title  \
# 0    UC3asD3ORk07XRPGC47hr-0w                              GNC NEWS 360
# 1    UCkmLoDQ8AVKwEsDSJtNKmug                                 WOLD NEWS
# 2    UC1Dlsbku0-iCGc0rXgQpDHQ                            Amaizing Facts
# 3    UC3-n3-ScTQLQ_Gc2tNLJreg  Stakelbeck Tonight with Erick Stakelbeck
# 4    UCF9LFWX5cdGHBg_FDm6tFrQ                           Breezy Politics
# ..                        ...                                       ...
# 216  UCfmSignFWkk1lw4015hCyyQ                               StandWithUs
# 217  UC16niRr50-MSBwiO3YDb3RA                                  BBC News
# 218  UCHpw8xwDNhU9gdohEcJu4aA                              The Guardian
# 219  UCm7lHFkt2yB_WzL67aruVBQ                           Hindustan Times
# 220  UCupvZG-5ko_eiXAupbDfxWw                                       CNN
#
#                                            description  \
# 0    🌍 Welcome to GNC – Global News Channel! 🌍\n\nA...
# 1                                   Subscribe  for USA
# 2    Target Subscribers 1 Million\n\nHello everyone...
# 3    Welcome to the Stakelbeck Tonight with Erick S...
# 4                             Politics By The People.
# ..                                                 ...
# 216  Fighting Antisemitism and Supporting Israel Ar...
# 217  Welcome to the official BBC News YouTube chann...
# 218  The Guardian brings you news, documentaries, a...
# 219  Hindustan Times Videos bring you news, views a...
# 220  CNN is the world leader in news and informatio...
#
#                     published_at country   view_count  comment_count  \
# 0    2024-09-22T02:57:31.675741Z      US         7096              0
# 1    2024-08-31T21:48:41.363607Z      US       372583              0
# 2    2024-06-05T10:37:49.325123Z      PK     84711317              0
# 3    2024-05-03T21:23:42.240192Z      US      2423653              0
# 4    2024-02-24T18:00:09.134775Z      US    101447822              0
# ..                           ...     ...          ...            ...
# 216         2006-06-06T22:44:08Z      IL     44427727              0
# 217         2006-04-08T05:51:05Z      GB   5607586404              0
# 218         2006-02-15T03:22:40Z      GB    729761411              0
# 219         2005-11-16T02:41:16Z      IN   5607879981              0
# 220         2005-10-02T16:06:36Z     NaN  16751878276              0
#
#      subscriber_count  video_count  is_verified  \
# 0                  27           20        False
# 1                 481          275        False
# 2              238000          412        False
# 3               31300           70        False
# 4              206000          575        False
# ..                ...          ...          ...
# 216            192000         1465        False
# 217          16800000        23220        False
# 218           2290000         7250        False
# 219           7370000        69366        False
# 220          17100000       167408        False
#
#                                               keywords  \
# 0                                                  NaN
# 1                  trump noticia "kamalla harris" vote
# 2    short shorts animals viral edits israel palest...
# 3    "erick stakelbeck" "the watchman with erick st...
# 4                                                  NaN
# ..                                                 ...
# 216  standwithus Israel Education activism pro-isra...
# 217                  BBC News Official YouTube Channel
# 218  guardian news film video environment documenta...
# 219  "world news" "us news" "HT world" "Hindustan T...
# 220                CNN "CNN News" news "breaking news"
#
#                                    profile_picture_url
# 0    https://yt3.ggpht.com/rE7KFfBo-a7KVXDR2xtVoESi...
# 1    https://yt3.ggpht.com/VZXxIUrbv9NoSwomQz_4sOlC...
# 2    https://yt3.ggpht.com/dCjKkhHRFEPvorpV1vhdD1XT...
# 3    https://yt3.ggpht.com/Oz0YlzbQAiPwkqA0vH1832AL...
# 4    https://yt3.ggpht.com/I5YmN4cKN0Vaon04Qs9hBbF2...
# ..                                                 ...
# 216  https://yt3.ggpht.com/ytc/AIdro_mh8eN8fDlZehoy...
# 217  https://yt3.ggpht.com/y_esGAQOhX4rTpWvrALErAJl...
# 218  https://yt3.ggpht.com/P7QrZEnioCzOeKA2sWKyxvR5...
# 219  https://yt3.ggpht.com/rxxycwwjFXuC-eQNBcklj4P-...
# 220  https://yt3.ggpht.com/n5DRh94eycw6xGcOKTn6LKQw...
#
# [218 rows x 12 columns]

# %% [markdown]
# ## Download de Bases Pré-Treinadas

# %%
# !pip install nltk

import nltk

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('rslp')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')
nltk.download('punkt')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.6)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package rslp to /root/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Limpeza Textual

# %%
# !pip install ftfy
# !pip install apyori

import csv
import re
import ftfy
from nltk.corpus import stopwords

import pandas as pd
# Out:
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (6.3.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy) (0.2.13)
# Requirement already satisfied: apyori in /usr/local/lib/python3.10/dist-packages (1.1.2)

# %%
# Função para extrair URLs
def extract_urls(comment):
    url_pattern = r'https?://\S+|www\.\S+'
    return re.findall(url_pattern, comment)

# Função para extrair menções
def extract_mentions(comment):
    mention_pattern = r'@[\w]+'
    return re.findall(mention_pattern, comment)

# Aplicando as funções para criar as novas colunas
palestine_df_comments['urls'] = palestine_df_comments['comment'].apply(extract_urls)
palestine_df_comments['mentions'] = palestine_df_comments['comment'].apply(extract_mentions)

# %% [markdown]
# ## Limpeza de texto

# %%
def clean_data(text):
    text = str(text)
    text = ftfy.fix_text(text)  # Corrige erros de codificação de text
    text = text.split("#")[0]
    text = text.split("https://")[0]
    text = re.sub(r'k{2,}', '', text) # Remover a sequência  de k's
    text = re.sub(r'\d+', '', text)  # Remove números
    text = re.sub(r'@\w+\s?', '', str(text))  # Remove o padrão "@algumusuario"
    text = re.sub(r'\bRT\b', '', text, flags=re.IGNORECASE)  # Remove a sequência "RT"
    text = re.sub(r'\s?:\s?', ' ', text)  # Remove o símbolo " : "
    text = re.sub(r'https://\S+', '', text)  # Remove trechos que começam com "https://" seguidos por qualquer sequência de caracteres não espaços em branco
    text = re.sub(r'http://\S+', '', text)  # Remove trechos que começam com "http://" seguidos por qualquer sequência de caracteres não espaços em branco
    text = re.sub(r'[^\w\s]|_+', '', text)  # Remove emojis
    text = re.sub(r'"', '', text)  # Remove aspas
    text = re.sub(r'[^\w\s]', '', text)  # Remove pontuação
    text = re.sub(r'mention', '', text) # Remover a palavra "mention"
    text = re.sub(r'馃', 'c', text) # Decodificar o caractere 'ç'
    text = re.sub(r'[^a-zA-Z\s]', '', text) # Manter apenas palavras no nosso alfabeto

    return text

def clean_data_and_save(df, input_dir=None, output_dir=None):
  if ( input_dir ):
    df = pd.read_csv(input_dir, encoding='utf-8')
  df['comment'] = df['comment'].apply(clean_data)
  if ( output_dir ):
    df.to_csv(output_dir, index=False, encoding='utf-8')
  return df

# %%
palestine_df_comments = clean_data_and_save(palestine_df_comments)

# %% [markdown]
# ## Remoção de StopWords

# %%
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    if isinstance(text, str):
        filtered_text = ' '.join([word for word in text.split() if word.lower() not in stop_words])
        return filtered_text
    else:
        return text

def remove_stopword_and_save(df, input_dir=None, output_dir=None):
  if ( input_dir ): df = pd.read_csv(input_dir, encoding='utf-8')
  df['comment'] = df['comment'].apply(remove_stopwords)

  if ( output_dir ):df.to_csv(output_dir, index=False, encoding='utf-8')
  return df

# %%
palestine_df_comments = remove_stopword_and_save(palestine_df_comments)

# %% [markdown]
# ## Transformação de tweets em minúsculos e lematização

# %%
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

# Inicializar lematizador
lemmatizer = WordNetLemmatizer()

# Função para lematização
def lemmatize_text(text):
    words = text.split()  # Separar o texto em palavras
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

def preprocess_lower(text):
    if isinstance(text, str):
        tokens = nltk.word_tokenize(text.lower(), language='english')
        text = ' '.join(tokens)
        text = lemmatize_text(text)
        return text
    else:
        return text

def preprocess_lower_and_save(df, input_dir=None, output_dir=None):
  if ( input_dir ): df = pd.read_csv(input_dir, encoding='utf-8')
  df['comment'] = df['comment'].apply(preprocess_lower)

  if ( output_dir): df.to_csv(output_dir, index=False, encoding='utf-8')
  return df

# %%
palestine_df_comments = preprocess_lower_and_save(palestine_df_comments)

# %% [markdown]
# ## Remoção de linhas em branco##

# %%
def remove_empty_line_and_save(df, input_dir=None, output_dir=None):
  if ( input_dir ): pd.read_csv(input_dir, encoding='utf-8')

  df.dropna(subset=['comment'], inplace=True)
  df = df[df['comment'].str.strip() != '']

  if ( output_dir ): df.to_csv(output_dir, index=False, encoding='utf-8')
  return df

# %%
palestine_df_comments = remove_empty_line_and_save(palestine_df_comments, output_dir='{country}_finalData.csv'.format(country='palestine'))

# %% [markdown]
# ## Resultado

# %%
import pandas as pd

def compare_dataframes(df1, df2, columns):
    """
    Compara dois DataFrames com base na quantidade de valores nulos, não nulos e valores únicos nas colunas especificadas.

    Parâmetros:
    - df1, df2: DataFrames a serem comparados.
    - columns: Lista de colunas a serem analisadas.

    Retorna:
    - Um dicionário com DataFrames para o resumo comparativo das métricas no formato especificado.
    """
    # Listas para armazenar os resultados de nulos, não nulos e valores únicos
    non_null_data = []
    null_data = []
    unique_data = []

    # Itera sobre as colunas para calcular métricas
    for col in columns:
        # Cálculo dos valores não nulos
        non_null_row = {
            "Coluna": col,
            "Original": df1[col].notna().sum(),
            "Após Tratamento": df2[col].notna().sum(),
            "Diferença": df1[col].notna().sum() - df2[col].notna().sum()
        }
        non_null_data.append(non_null_row)

        # Cálculo dos valores nulos
        null_row = {
            "Coluna": col,
            "Original": df1[col].isna().sum(),
            "Após Tratamento": df2[col].isna().sum(),
            "Diferença": df1[col].isna().sum() - df2[col].isna().sum()
        }
        null_data.append(null_row)

        # Cálculo dos valores únicos
        unique_row = {
            "Coluna": col,
            "Original": df1[col].nunique(),
            "Após Tratamento": df2[col].nunique(),
            "Diferença": df1[col].nunique() - df2[col].nunique()
        }
        unique_data.append(unique_row)

    # Converte as listas em DataFrames para os nulos, não nulos e valores únicos
    non_null_df = pd.DataFrame(non_null_data)
    null_df = pd.DataFrame(null_data)
    unique_df = pd.DataFrame(unique_data)

    # Retorna um dicionário com os DataFrames no formato desejado
    return {
        "Valores Não Nulos": non_null_df,
        "Valores Nulos": null_df,
        "Valores Únicos": unique_df
    }

# Exemplo de uso
# df1 e df2 são os seus DataFrames de entrada
columns = ['comment_id', 'author_channel_id', 'author', 'author_channel_url', 'video_id', 'channel_id']
resultado_comparacao = compare_dataframes(original_comments, palestine_df_comments, columns)

# Exibindo os resultados
print("=== Valores Não Nulos ===")
print(resultado_comparacao["Valores Não Nulos"])

print("\n=== Valores Nulos ===")
print(resultado_comparacao["Valores Nulos"])

print("\n=== Valores Únicos ===")
print(resultado_comparacao["Valores Únicos"])
# Out:
# === Valores Não Nulos ===
#                Coluna  Original  Após Tratamento  Diferença
# 0          comment_id    814975           717667      97308
# 1   author_channel_id    814975           717667      97308
# 2              author    814303           717041      97262
# 3  author_channel_url    814975           717667      97308
# 4            video_id    814975           717667      97308
# 5          channel_id    814975           717667      97308
#
# === Valores Nulos ===
#                Coluna  Original  Após Tratamento  Diferença
# 0          comment_id         0                0          0
# 1   author_channel_id         0                0          0
# 2              author       672              626         46
# 3  author_channel_url         0                0          0
# 4            video_id         0                0          0
# 5          channel_id         0                0          0
#
# === Valores Únicos ===
#                Coluna  Original  Após Tratamento  Diferença
# 0          comment_id    814584           717667      96917
# 1   author_channel_id    361225           320366      40859
# 2              author    361247           320371      40876
# 3  author_channel_url    361459           320569      40890
# 4            video_id       811              805          6
# 5          channel_id       221              217          4

# %% [markdown]
# ## Remoção de Valores Nulos
#
# É melhor excluir os comentários que não é possível identificar o comment_id, por poderem se tratar de valores repetidos. A mesma coisa para os usuários que não possuem user_channel_id preenchido, não sendo possível identifica-los posteriormente. A coluna author_channel_id foi identificada como a chave única de usuário porque, diferente dos campos author e author_channel_url, não podem ser modificadas dentro do sistema, podendo nos levar a crer que se tratam de usuários distintos quando não o são. Dentre as demais features, não temos valores nulos.

# %%
duplicates = palestine_df_comments.groupby('author_channel_id').agg({
    'author': lambda x: list(x),
    'author_channel_url': lambda x: list(x)
}).reset_index()

# Filtrando apenas aqueles que têm mais de um autor ou URL
duplicates = duplicates[(duplicates['author'].apply(lambda x: len(set(x))) > 1) |
                        (duplicates['author_channel_url'].apply(lambda x: len(set(x))) > 1)]

print("\n=== Valores de author_channel_id com mais de um valor de author ou author_channel_url ===")
for index, row in duplicates.iterrows():
    print(f"\nAuthor Channel ID: {row['author_channel_id']}")
    print(f"Autores: {', '.join(set(row['author']))}")
    print(f"URLs de Channel: {', '.join(set(row['author_channel_url']))}")
# Out:
# === Valores de author_channel_id com mais de um valor de author ou author_channel_url ===
#
# Author Channel ID: UC-5h4iunFKV_q038Y_O0rbQ
# Autores: @troll3497, @Internet_God
# URLs de Channel: http://www.youtube.com/@troll3497, http://www.youtube.com/@Internet_God
#
# Author Channel ID: UC-FGO7XzxrqM1Ug0GokNM2A
# Autores: @AMIkoroma, @Agrig-tu
# URLs de Channel: http://www.youtube.com/@AMIkoroma, http://www.youtube.com/@Agrig-tu
#
# Author Channel ID: UC-bx-EqZV0J7iUOtj4bDMNQ
# Autores: @Illegal-y7m, @SoupNazi-x2o
# URLs de Channel: http://www.youtube.com/@Illegal-y7m, http://www.youtube.com/@SoupNazi-x2o
#
# Author Channel ID: UC0HxMvP-W23HSgiAzaTTEeQ
# Autores: @severalwolves, @AwesometownUSA
# URLs de Channel: http://www.youtube.com/@AwesometownUSA, http://www.youtube.com/@severalwolves
#
# Author Channel ID: UC0ulPlEXSMycImSlDXyYtPw
# Autores: @TomPeranic, @TomPistol
# URLs de Channel: http://www.youtube.com/@TomPeranic, http://www.youtube.com/@TomPistol
#
# Author Channel ID: UC1PDRiL7rxPyqnozs5vBMoQ
# Autores: @UjjainwalaOanali, @Papaloana
# URLs de Channel: http://www.youtube.com/@UjjainwalaOanali, http://www.youtube.com/@Papaloana
#
# Author Channel ID: UC2CVRB8IYNEAISEdy-73KZQ
# Autores: @hasmatarakoly1524, @hasmatarakoly
# URLs de Channel: http://www.youtube.com/@hasmatarakoly1524, http://www.youtube.com/@hasmatarakoly
#
# Author Channel ID: UC2HqzvIG-KMCHlFHZlCgV1Q
# Autores: @H2oog667, @H2oog33
# URLs de Channel: http://www.youtube.com/@H2oog667, http://www.youtube.com/@H2oog33
#
# Author Channel ID: UC2PrkN_YOFCg9vXZmaqJLMA
# Autores: @lannre00, @lanresholaja3233
# URLs de Channel: http://www.youtube.com/@lanresholaja3233, http://www.youtube.com/@lannre00
#
# Author Channel ID: UC2Z2DUsCGgaaJauoDWPxg0w
# Autores: @Go_Home_British_Raj, @JonTeriini
# URLs de Channel: http://www.youtube.com/@Go_Home_British_Raj, http://www.youtube.com/@JonTeriini
#
# Author Channel ID: UC2y7-XBIIIISRUaMtCgvOhg
# Autores: @Chapri_Modi_ChappalChor, @Ahimsa_paramo_dharma
# URLs de Channel: http://www.youtube.com/@Chapri_Modi_ChappalChor, http://www.youtube.com/@Ahimsa_paramo_dharma
#
# Author Channel ID: UC370ExU478OuhfDQ92DUaqg
# Autores: @mohangowda3667, @TejaPrashanth2
# URLs de Channel: http://www.youtube.com/@mohangowda3667, http://www.youtube.com/@TejaPrashanth2
#
# Author Channel ID: UC3RxWWSu4gnviMQXMpyD_BQ
# Autores: @convergentradius, @n.rv..n
# URLs de Channel: http://www.youtube.com/@n.rv..n, http://www.youtube.com/@convergentradius
#
# Author Channel ID: UC3YS15C9z9zeMtK6-MpMC1w
# Autores: @Narconoob-o3t, @Speed1-t2s
# URLs de Channel: http://www.youtube.com/@Narconoob-o3t, http://www.youtube.com/@Speed1-t2s
#
# Author Channel ID: UC4646yd3lcufsIW16sTf_xg
# Autores: @nethanyahu, @yoohanies
# URLs de Channel: http://www.youtube.com/@nethanyahu, http://www.youtube.com/@yoohanies
#
# Author Channel ID: UC4AHs5WgrbSSzjssvxbTp6g
# Autores: @Adventure-y1y, @Yahoo-j4b
# URLs de Channel: http://www.youtube.com/@Adventure-y1y, http://www.youtube.com/@Yahoo-j4b
#
# Author Channel ID: UC4JrjHKh-5mPVgFzQzevTUQ
# Autores: @MarkGenner-xz4zu, @MarkGenner1991
# URLs de Channel: http://www.youtube.com/@MarkGenner1991, http://www.youtube.com/@MarkGenner-xz4zu
#
# Author Channel ID: UC4btBZcstMPl6HvD2c_SWVQ
# Autores: @123watc, @Jeff-Mr
# URLs de Channel: http://www.youtube.com/@Jeff-Mr, http://www.youtube.com/@123watc
#
# Author Channel ID: UC4ywwwEAza4bMNu5Afn2Yqg
# Autores: @democracyforall, @MotherRussiaisforever
# URLs de Channel: http://www.youtube.com/@democracyforall, http://www.youtube.com/@MotherRussiaisforever
#
# Author Channel ID: UC5O8KoNwF_e6mtsmgh_6bmg
# Autores: @Apocalyptic_Revelation, @Fear_g-o-d
# URLs de Channel: http://www.youtube.com/@Apocalyptic_Revelation, http://www.youtube.com/@Fear_g-o-d
#
# Author Channel ID: UC5cUy2J9e6b3LmsUmcqb_6A
# Autores: @Pathan786ShortVideos, @Pathan109ShortVideos
# URLs de Channel: http://www.youtube.com/@Pathan109ShortVideos, http://www.youtube.com/@Pathan786ShortVideos
#
# Author Channel ID: UC5u8sEJapJFlgUuY_uLlXrQ
# Autores: @Herreralalola123, @jacquelineverswalm1722
# URLs de Channel: http://www.youtube.com/@jacquelineverswalm1722, http://www.youtube.com/@Herreralalola123
#
# Author Channel ID: UC6upYkTAW84pp3sqKy9ZQPQ
# Autores: @GLau9494, @Georgialauren1994
# URLs de Channel: http://www.youtube.com/@GLau9494, http://www.youtube.com/@Georgialauren1994
#
# Author Channel ID: UC7Cixp71tR5-8ZAuTcjQeHg
# Autores: @axebearer, @waraidako
# URLs de Channel: http://www.youtube.com/@waraidako, http://www.youtube.com/@axebearer
#
# Author Channel ID: UC7WIatb4PR3wReIvWdp7AqA
# Autores: @rodrigo4reel, @dr3wdaoxide
# URLs de Channel: http://www.youtube.com/@dr3wdaoxide, http://www.youtube.com/@rodrigo4reel
#
# Author Channel ID: UC7oljeRYl2XM1APEwvhRO7w
# Autores: @GlobexCorporationHank, @alihussain4349
# URLs de Channel: http://www.youtube.com/@GlobexCorporationHank, http://www.youtube.com/@alihussain4349
#
# Author Channel ID: UC8039k_xbKxa3hORK_My1Zg
# Autores: @schlafcomandante5662, @schlafcomandanten
# URLs de Channel: http://www.youtube.com/@schlafcomandanten, http://www.youtube.com/@schlafcomandante5662
#
# Author Channel ID: UC89qjubW4_ehkCbKhlHnDnQ
# Autores: @Sammy_Kaur, @Sammy_Francis
# URLs de Channel: http://www.youtube.com/@Sammy_Kaur, http://www.youtube.com/@Sammy_Francis
#
# Author Channel ID: UC8_aEe1G-mLzixPT45Dnzgg
# Autores: @FtheJuice1888, @AdolfEdelstein
# URLs de Channel: http://www.youtube.com/@AdolfEdelstein, http://www.youtube.com/@FtheJuice1888
#
# Author Channel ID: UC8oiZT1w1oIZEgu18BEstQw
# Autores: @alokbhoi8757, @CHATGPT248
# URLs de Channel: http://www.youtube.com/@CHATGPT248, http://www.youtube.com/@alokbhoi8757
#
# Author Channel ID: UC8yn7nHtZRS6yS9XDNa_Jzw
# Autores: @AverageKashmiriMilitant, @IDrinkSaudiOil
# URLs de Channel: http://www.youtube.com/@AverageKashmiriMilitant, http://www.youtube.com/@IDrinkSaudiOil
#
# Author Channel ID: UC9g0vu7vD5wgfmR1O19137g
# Autores: @Randy-xv8sf, @RandallHicks-xv8sf
# URLs de Channel: http://www.youtube.com/@RandallHicks-xv8sf, http://www.youtube.com/@Randy-xv8sf
#
# Author Channel ID: UC9vU0h9b8dDARm_sFc208zQ
# Autores: @modulakgotlasebe7444, @Obfanteri5678
# URLs de Channel: http://www.youtube.com/@modulakgotlasebe7444, http://www.youtube.com/@Obfanteri5678
#
# Author Channel ID: UCB0PvulqhkqwVwafO_Ngavw
# Autores: @Stefch2, @StephanChasse-t1z
# URLs de Channel: http://www.youtube.com/@Stefch2, http://www.youtube.com/@StephanChasse-t1z
#
# Author Channel ID: UCB0_wHo4mMh7PAq757uHxpA
# Autores: @AaronFromGuildford, @AaronBr00mfie7d
# URLs de Channel: http://www.youtube.com/@AaronBr00mfie7d, http://www.youtube.com/@AaronFromGuildford
#
# Author Channel ID: UCBFZw2H8mrtGfowt0WQ_2aQ
# Autores: @Lets.stop.oil.protesters, @God-protect-the-IDF-and-israel
# URLs de Channel: http://www.youtube.com/@God-protect-the-IDF-and-israel, http://www.youtube.com/@Lets.stop.oil.protesters
#
# Author Channel ID: UCBcb4IoOdUjloW6MLWHKdNg
# Autores: @yeasinahmed3788, @Gericho007
# URLs de Channel: http://www.youtube.com/@yeasinahmed3788, http://www.youtube.com/@Gericho007
#
# Author Channel ID: UCBkKFPR6lgzXHsixyL_vweQ
# Autores: @annbell2538, @Diddydiditt
# URLs de Channel: http://www.youtube.com/@annbell2538, http://www.youtube.com/@Diddydiditt
#
# Author Channel ID: UCBuEjNUnsJnJBsCJ2gt-9rg
# Autores: @Manselior, @Raemundy_Syerhilza
# URLs de Channel: http://www.youtube.com/@Manselior, http://www.youtube.com/@Raemundy_Syerhilza
#
# Author Channel ID: UCC8nop3QdYJTP_9W9UxUgQA
# Autores: @ZahraMHK, @Lilly-z1x2m
# URLs de Channel: http://www.youtube.com/@ZahraMHK, http://www.youtube.com/@Lilly-z1x2m
#
# Author Channel ID: UCCBNrGA46-VhqOeew-FSsRw
# Autores: @FreedomTruthBoldness, @FREEDOM1TRUTH1BOLDNESS
# URLs de Channel: http://www.youtube.com/@FREEDOM1TRUTH1BOLDNESS, http://www.youtube.com/@FreedomTruthBoldness
#
# Author Channel ID: UCCNn0wWWapbGBU_dmiL55Ww
# Autores: @oola-u-uber, @Mosinnkhaan
# URLs de Channel: http://www.youtube.com/@oola-u-uber, http://www.youtube.com/@Mosinnkhaan
#
# Author Channel ID: UCD56AD2UoMYS4lLiI6FiZfQ
# Autores: @kingfisher-n4y, @lat123x
# URLs de Channel: http://www.youtube.com/@lat123x, http://www.youtube.com/@kingfisher-n4y
#
# Author Channel ID: UCE7WfOUuIxq4cpoGBvdLTzw
# Autores: @Monakhalidi0513, @sarakhalidi0513
# URLs de Channel: http://www.youtube.com/@sarakhalidi0513, http://www.youtube.com/@Monakhalidi0513
#
# Author Channel ID: UCEVb4XuooITTvmZfXm_sC-A
# Autores: @JoeBiden-u4y, @Logence02
# URLs de Channel: http://www.youtube.com/@JoeBiden-u4y, http://www.youtube.com/@Logence02
#
# Author Channel ID: UCEimdM55-wcsx45XWxuAIBw
# Autores: @PaulHira, @Annon.yamous
# URLs de Channel: http://www.youtube.com/@PaulHira, http://www.youtube.com/@Annon.yamous
#
# Author Channel ID: UCEzCd6SzjNUvSySgI4TaFZg
# Autores: @TruthSeeker8147, @SeekingChaim
# URLs de Channel: http://www.youtube.com/@TruthSeeker8147, http://www.youtube.com/@SeekingChaim
#
# Author Channel ID: UCFM5YTLZIwR4D1l2HKXYVDg
# Autores: @interrobangings, @DDRWakaLaka
# URLs de Channel: http://www.youtube.com/@interrobangings, http://www.youtube.com/@DDRWakaLaka
#
# Author Channel ID: UCFqsdJ-S5brCxXyvjQiCtJg
# Autores: @piyushpant8085, @piyushpant166-e2n
# URLs de Channel: http://www.youtube.com/@piyushpant8085, http://www.youtube.com/@piyushpant166-e2n
#
# Author Channel ID: UCFqwlFvjc0jwHMBwpY7_06Q
# Autores: @JohnTeel79, @MelodyFarris2323
# URLs de Channel: http://www.youtube.com/@JohnTeel79, http://www.youtube.com/@MelodyFarris2323
#
# Author Channel ID: UCFzMbhQdkw7VU7ZC5hs1d6A
# Autores: @Smitty55888, @paulleary8594
# URLs de Channel: http://www.youtube.com/@paulleary8594, http://www.youtube.com/@Smitty55888
#
# Author Channel ID: UCG6xantM-WA7RxrlzG3rmSQ
# Autores: @IsraelDFender, @ISRAEL922IDF
# URLs de Channel: http://www.youtube.com/@ISRAEL922IDF, http://www.youtube.com/@IsraelDFender
#
# Author Channel ID: UCGE9exQJWrgHsCjIxirYjNw
# Autores: @Napolean_Dynamite, @Fuga_Mundi
# URLs de Channel: http://www.youtube.com/@Fuga_Mundi, http://www.youtube.com/@Napolean_Dynamite
#
# Author Channel ID: UCGOdEIRGNtLxAG65Qr8yo5w
# Autores: @Sidd111-p1b, @Siddhidatri143
# URLs de Channel: http://www.youtube.com/@Sidd111-p1b, http://www.youtube.com/@Siddhidatri143
#
# Author Channel ID: UCH7O1F2t5Xgvg6s2TKWi6sg
# Autores: @IWannaBeFamous647, @TimPool-b8z
# URLs de Channel: http://www.youtube.com/@TimPool-b8z, http://www.youtube.com/@IWannaBeFamous647
#
# Author Channel ID: UCH9xKbdUEhWdLvHmydRqwOg
# Autores: @Sid_Phillips_1984, @Ghazghkull_Thraka
# URLs de Channel: http://www.youtube.com/@Sid_Phillips_1984, http://www.youtube.com/@Ghazghkull_Thraka
#
# Author Channel ID: UCHABm7ji9EYW_zgiP2uEagg
# Autores: @কামলাদেশী, @Sanjibkumar-lc4oz
# URLs de Channel: http://www.youtube.com/@%E0%A6%95%E0%A6%BE%E0%A6%AE%E0%A6%B2%E0%A6%BE%E0%A6%A6%E0%A7%87%E0%A6%B6%E0%A7%80, http://www.youtube.com/@Sanjibkumar-lc4oz
#
# Author Channel ID: UCHDJw9WcuJorF23Nlv5OKBA
# Autores: @RahulDabhi6288, @nationalism_rahul
# URLs de Channel: http://www.youtube.com/@nationalism_rahul, http://www.youtube.com/@RahulDabhi6288
#
# Author Channel ID: UCHF-wtE5g6uQN-9O7JPG5ZA
# Autores: @0z0pk, @o.z.p.
# URLs de Channel: http://www.youtube.com/@0z0pk, http://www.youtube.com/@o.z.p.
#
# Author Channel ID: UCHLhVo5SehBQS-4ACG0VTBw
# Autores: @timenewskh, @pelvelea7
# URLs de Channel: http://www.youtube.com/@pelvelea7, http://www.youtube.com/@timenewskh
#
# Author Channel ID: UCHvzmJBdRwaidsVEjJSKO4A
# Autores: @Black_gay_trans_Jew_Indian_88, @Random_627A
# URLs de Channel: http://www.youtube.com/@Black_gay_trans_Jew_Indian_88, http://www.youtube.com/@Random_627A
#
# Author Channel ID: UCIdhvXLOOMDkxl_JhmMbHhw
# Autores: @Shaunkray, @Sonofephraim2
# URLs de Channel: http://www.youtube.com/@Shaunkray, http://www.youtube.com/@Sonofephraim2
#
# Author Channel ID: UCJ9IWVeS4OhFBfyNr_T7G2w
# Autores: @KatarinaKatrene, @Xatrene
# URLs de Channel: http://www.youtube.com/@KatarinaKatrene, http://www.youtube.com/@Xatrene
#
# Author Channel ID: UCJDM74ghT13vSI5IyXbDZkQ
# Autores: @JewTube-SS, @GsTq-j2e, @Kqlk-1
# URLs de Channel: http://www.youtube.com/@JewTube-SS, http://www.youtube.com/@Kqlk-1, http://www.youtube.com/@GsTq-j2e
#
# Author Channel ID: UCJEcljyuURAnwUqXSN0BESQ
# Autores: @PeekCandy, @The_Kinadian_Kid
# URLs de Channel: http://www.youtube.com/@The_Kinadian_Kid, http://www.youtube.com/@PeekCandy
#
# Author Channel ID: UCJdN24Ghc6hGIWDzud4gC-w
# Autores: @ahssanmoshref, @dont-side-with-genocide
# URLs de Channel: http://www.youtube.com/@dont-side-with-genocide, http://www.youtube.com/@ahssanmoshref
#
# Author Channel ID: UCK8uXUscY0d-2EWLq6a5ETg
# Autores: @Sunrisingromwest, @14Mehmet11
# URLs de Channel: http://www.youtube.com/@14Mehmet11, http://www.youtube.com/@Sunrisingromwest
#
# Author Channel ID: UCKAI2Y8-grJjyhHdVl9BOsA
# Autores: @morphicresonancechannel604, @morphicresonancechannel8733
# URLs de Channel: http://www.youtube.com/@morphicresonancechannel8733, http://www.youtube.com/@morphicresonancechannel604
#
# Author Channel ID: UCKoQdaICK4o-MWN62R3uPqQ
# Autores: @גבריאל1994, @Trabant601-94
# URLs de Channel: http://www.youtube.com/@%D7%92%D7%91%D7%A8%D7%99%D7%90%D7%9C1994, http://www.youtube.com/@Trabant601-94
#
# Author Channel ID: UCKx_qIF7Rq1izOvz8plwIqg
# Autores: @yq77777, @yq2266
# URLs de Channel: http://www.youtube.com/@yq77777, http://www.youtube.com/@yq2266
#
# Author Channel ID: UCLtqgPqkwYSK1bjQBOG0Kng
# Autores: @CBH-1969, @ChrisBH1969
# URLs de Channel: http://www.youtube.com/@CBH-1969, http://www.youtube.com/@ChrisBH1969
#
# Author Channel ID: UCMj_lbArUBmGecNDVgOe_XQ
# Autores: @DoncampbellUSMC1041, @DoncampbellUSMC
# URLs de Channel: http://www.youtube.com/@DoncampbellUSMC1041, http://www.youtube.com/@DoncampbellUSMC
#
# Author Channel ID: UCMosHeJYd9W1Km3ifNqt-3Q
# Autores: @yawzerdoink-a-sore-as, @yawzerdoink-a-sore-as8159
# URLs de Channel: http://www.youtube.com/@yawzerdoink-a-sore-as, http://www.youtube.com/@yawzerdoink-a-sore-as8159
#
# Author Channel ID: UCNZhJExT_psQ76Xnih44U3g
# Autores: @nyxboi427, @nyxnicks
# URLs de Channel: http://www.youtube.com/@nyxnicks, http://www.youtube.com/@nyxboi427
#
# Author Channel ID: UCNsdaLmq4HqxMNSs2pWZT6A
# Autores: @Aryna2005, @Butterfly1112.
# URLs de Channel: http://www.youtube.com/@Aryna2005, http://www.youtube.com/@Butterfly1112.
#
# Author Channel ID: UCOms_MJrMv4PZdKy3FN6i6w
# Autores: @Achie8283, @AhmadHassan-p7v6e
# URLs de Channel: http://www.youtube.com/@AhmadHassan-p7v6e, http://www.youtube.com/@Achie8283
#
# Author Channel ID: UCPXMyoJu8DCwP1_aJxk2L8g
# Autores: @zakeemax, @bubbathebarbarian
# URLs de Channel: http://www.youtube.com/@zakeemax, http://www.youtube.com/@bubbathebarbarian
#
# Author Channel ID: UCQEtRQKxoVIlQgB_VLtu6VQ
# Autores: @ICENOVA36, @AllForOne36
# URLs de Channel: http://www.youtube.com/@AllForOne36, http://www.youtube.com/@ICENOVA36
#
# Author Channel ID: UCQPves8LBIxE3NiliOST8Cg
# Autores: @Jaygunna-ki2bk, @Theonez321
# URLs de Channel: http://www.youtube.com/@Jaygunna-ki2bk, http://www.youtube.com/@Theonez321
#
# Author Channel ID: UCQqvNEUbGKg-kFvWlgXI9zQ
# Autores: @Shroooms, @sacredamex
# URLs de Channel: http://www.youtube.com/@sacredamex, http://www.youtube.com/@Shroooms
#
# Author Channel ID: UCRwbYKvLJaNPQdCQDOFpm8g
# Autores: @Think_and_Reflect, @shabeerali1256
# URLs de Channel: http://www.youtube.com/@shabeerali1256, http://www.youtube.com/@Think_and_Reflect
#
# Author Channel ID: UCSOBgpL39coCiEN6hN7eJaQ
# Autores: @roseonmars-06, @ModiG-69
# URLs de Channel: http://www.youtube.com/@roseonmars-06, http://www.youtube.com/@ModiG-69
#
# Author Channel ID: UCSlLAXEvXKH0PGY0T0k_iwA
# Autores: @jabeensyeda4981, @RedRose0786
# URLs de Channel: http://www.youtube.com/@RedRose0786, http://www.youtube.com/@jabeensyeda4981
#
# Author Channel ID: UCTJSQa--Oj__aBId7pTSWpQ
# Autores: @Dhaka_mapping, @Bangladesh-mapper99
# URLs de Channel: http://www.youtube.com/@Dhaka_mapping, http://www.youtube.com/@Bangladesh-mapper99
#
# Author Channel ID: UCTM21uTOp0gqAT7Nc3zaSWw
# Autores: @RobTheTruth, @RabbiMurray
# URLs de Channel: http://www.youtube.com/@RabbiMurray, http://www.youtube.com/@RobTheTruth
#
# Author Channel ID: UCTbp52rJh47CGccScpoUg7g
# Autores: @Sports71Dhk, @Defence71BD, @BD-defenses
# URLs de Channel: http://www.youtube.com/@BD-defenses, http://www.youtube.com/@Sports71Dhk, http://www.youtube.com/@Defence71BD
#
# Author Channel ID: UCUZTKlwlfgu5KK974ia72GQ
# Autores: @Dioriohagu, @Chaoswalker.
# URLs de Channel: http://www.youtube.com/@Chaoswalker., http://www.youtube.com/@Dioriohagu
#
# Author Channel ID: UCUjj_BQkilvl6YXD_7SH7Kg
# Autores: @10chocolatefingers, @Jeromevandermeulen
# URLs de Channel: http://www.youtube.com/@Jeromevandermeulen, http://www.youtube.com/@10chocolatefingers
#
# Author Channel ID: UCV31QUPfUY1Iy8GByU3ew1A
# Autores: @ashlie9482, @Ukhti_Asiyah
# URLs de Channel: http://www.youtube.com/@Ukhti_Asiyah, http://www.youtube.com/@ashlie9482
#
# Author Channel ID: UCVFGPz96TOzI3_hy-JhznIg
# Autores: @FoenixCollective, @XIONI5TSLAYER, @SlMORRG
# URLs de Channel: http://www.youtube.com/@XIONI5TSLAYER, http://www.youtube.com/@SlMORRG, http://www.youtube.com/@FoenixCollective
#
# Author Channel ID: UCVx3Y7SVQCJdNpmyFg1mAyA
# Autores: @vincmahara9543, @vincmahara10101
# URLs de Channel: http://www.youtube.com/@vincmahara10101, http://www.youtube.com/@vincmahara9543
#
# Author Channel ID: UCW2BOUiItEC9wPxO3PGubeA
# Autores: @EloiseB2025, @EloiseBridgertonFan
# URLs de Channel: http://www.youtube.com/@EloiseB2025, http://www.youtube.com/@EloiseBridgertonFan
#
# Author Channel ID: UCWL1wRksEQ3fyyZDkCw7NkA
# Autores: @rob.maramé, @maramé.r
# URLs de Channel: http://www.youtube.com/@rob.maram%C3%A9, http://www.youtube.com/@maram%C3%A9.r
#
# Author Channel ID: UCWZAmEZM8tYgLbCYTHa5IZw
# Autores: @Smelltheflowers1413, @Whatiftheresmore1314
# URLs de Channel: http://www.youtube.com/@Whatiftheresmore1314, http://www.youtube.com/@Smelltheflowers1413
#
# Author Channel ID: UCXaCLcPzdZ8ahBYmAqr-6iw
# Autores: @christinewyatt234, @christinewyatt4794
# URLs de Channel: http://www.youtube.com/@christinewyatt234, http://www.youtube.com/@christinewyatt4794
#
# Author Channel ID: UCXedHZOTVviyzc0b_FxgyQQ
# Autores: @greaterislam2201, @اکرام-غ2ذ
# URLs de Channel: http://www.youtube.com/@%D8%A7%DA%A9%D8%B1%D8%A7%D9%85-%D8%BA2%D8%B0, http://www.youtube.com/@greaterislam2201
#
# Author Channel ID: UCXr0v2bC9mzPL_rFYMFcP8w
# Autores: @ShyamjeeJha-rv7fq, @truesame450
# URLs de Channel: http://www.youtube.com/@truesame450, http://www.youtube.com/@ShyamjeeJha-rv7fq
#
# Author Channel ID: UCXtgF8D3-ewnbG7QZqL82lA
# Autores: @freeBalochistan-n7l, @gods-best-friend-gbf
# URLs de Channel: http://www.youtube.com/@freeBalochistan-n7l, http://www.youtube.com/@gods-best-friend-gbf
#
# Author Channel ID: UCYM2YyVa_RuZBkP6NW_4S-Q
# Autores: @LouisFood, @AlphaStory00
# URLs de Channel: http://www.youtube.com/@LouisFood, http://www.youtube.com/@AlphaStory00
#
# Author Channel ID: UCYkPEbDNlYSYFEaQDTbZi7A
# Autores: @NotKimiRaikkonen, @NotKimiRaikkonen1
# URLs de Channel: http://www.youtube.com/@NotKimiRaikkonen, http://www.youtube.com/@NotKimiRaikkonen1
#
# Author Channel ID: UCYoaHez7wJKZPTXJ9YHeDjA
# Autores: @ramroum1783, @rom1783-c1y
# URLs de Channel: http://www.youtube.com/@rom1783-c1y, http://www.youtube.com/@ramroum1783
#
# Author Channel ID: UCZDYFM1nR0SZoBgNFMYMSFA
# Autores: @ruairijoseph, @LuckyRufey
# URLs de Channel: http://www.youtube.com/@LuckyRufey, http://www.youtube.com/@ruairijoseph
#
# Author Channel ID: UCZTyOCZ7uoSb7zO0XsNLFgQ
# Autores: @DiegoTTesla, @KlausSchwabb
# URLs de Channel: http://www.youtube.com/@KlausSchwabb, http://www.youtube.com/@DiegoTTesla
#
# Author Channel ID: UCZU63CtfFVVFTuapXgEh2Cg
# Autores: @Revival-u6s, @Shoulda_left_Israel_alone
# URLs de Channel: http://www.youtube.com/@Shoulda_left_Israel_alone, http://www.youtube.com/@Revival-u6s
#
# Author Channel ID: UCZiEOCcdmvtJjbadsJuRXdQ
# Autores: @Zerrssddg, @SudiptaJha-z3r
# URLs de Channel: http://www.youtube.com/@Zerrssddg, http://www.youtube.com/@SudiptaJha-z3r
#
# Author Channel ID: UCZpRaXV_qt9_NZv8f2IFphA
# Autores: @Mominaaejaz, @MominaMomin-m6i
# URLs de Channel: http://www.youtube.com/@Mominaaejaz, http://www.youtube.com/@MominaMomin-m6i
#
# Author Channel ID: UC_2QXLMJnBG-Hg3mN3l6yQQ
# Autores: @Btval, @mval560
# URLs de Channel: http://www.youtube.com/@mval560, http://www.youtube.com/@Btval
#
# Author Channel ID: UC_6e8EIYQmN9Jv1UUXAJWWA
# Autores: @Hfgjdsrgtgbh-kr4yj, @Bhagwadav-kr4yj
# URLs de Channel: http://www.youtube.com/@Bhagwadav-kr4yj, http://www.youtube.com/@Hfgjdsrgtgbh-kr4yj
#
# Author Channel ID: UC_WfoOqxed7gBHydgX6HvmQ
# Autores: @Mississippicommunistparty, @MississippiREDstar
# URLs de Channel: http://www.youtube.com/@Mississippicommunistparty, http://www.youtube.com/@MississippiREDstar
#
# Author Channel ID: UC_d55zmPE7d9QkQzaePGQeA
# Autores: @mankojin, @baretta-m7i
# URLs de Channel: http://www.youtube.com/@baretta-m7i, http://www.youtube.com/@mankojin
#
# Author Channel ID: UC_fgJLfn-CJ-RurnOzQBEzQ
# Autores: @SHAHABUDDINKHAN719, @BaapofHindusAbdul
# URLs de Channel: http://www.youtube.com/@SHAHABUDDINKHAN719, http://www.youtube.com/@BaapofHindusAbdul
#
# Author Channel ID: UCa01vWiK4AoxG0rV7PJ9LRg
# Autores: @carbonfibremadness, @WeRSinwar
# URLs de Channel: http://www.youtube.com/@WeRSinwar, http://www.youtube.com/@carbonfibremadness
#
# Author Channel ID: UCa1O81NxpALj7yQaEnBYwdA
# Autores: @YoutubeDictatorship2024, @-Believeinyourself-
# URLs de Channel: http://www.youtube.com/@-Believeinyourself-, http://www.youtube.com/@YoutubeDictatorship2024
#
# Author Channel ID: UCaBnGwInPLpch7vRpuf1Yvw
# Autores: @hardydragon3, @crazydragon8-t
# URLs de Channel: http://www.youtube.com/@hardydragon3, http://www.youtube.com/@crazydragon8-t
#
# Author Channel ID: UCa_CDY-XIMEkntG0CO-UyHQ
# Autores: @QSVY-n1v, @queenschannel2136
# URLs de Channel: http://www.youtube.com/@queenschannel2136, http://www.youtube.com/@QSVY-n1v
#
# Author Channel ID: UCai07UA6o7TMyn27ETR8R_A
# Autores: @evanbarbacenabuarao, @evanebb
# URLs de Channel: http://www.youtube.com/@evanbarbacenabuarao, http://www.youtube.com/@evanebb
#
# Author Channel ID: UCb8dUp5orgvH4cjwuBaTEKg
# Autores: @ThorToshi, @TohrrTosh
# URLs de Channel: http://www.youtube.com/@ThorToshi, http://www.youtube.com/@TohrrTosh
#
# Author Channel ID: UCblg76ToSzOMZQ8pbcLwPMg
# Autores: @OverhaulOfficial, @Hailzua
# URLs de Channel: http://www.youtube.com/@Hailzua, http://www.youtube.com/@OverhaulOfficial
#
# Author Channel ID: UCbmJsCWC0zLvjmnmSbnjRSg
# Autores: @VLADTHEINHALER_1, @GERONIMO619
# URLs de Channel: http://www.youtube.com/@GERONIMO619, http://www.youtube.com/@VLADTHEINHALER_1
#
# Author Channel ID: UCbx-D-2TmtlVrZof4lEfEhQ
# Autores: @Pantherqueen-r2i, @Isaaf-w8b
# URLs de Channel: http://www.youtube.com/@Pantherqueen-r2i, http://www.youtube.com/@Isaaf-w8b
#
# Author Channel ID: UCd2z4Bh9BzifcU8ywsGNtng
# Autores: @Free2BHuman, @777-u8i
# URLs de Channel: http://www.youtube.com/@Free2BHuman, http://www.youtube.com/@777-u8i
#
# Author Channel ID: UCdh0YpDEbOCi102XC06KtHg
# Autores: @slickperspective, @slickperspective2745
# URLs de Channel: http://www.youtube.com/@slickperspective2745, http://www.youtube.com/@slickperspective
#
# Author Channel ID: UCeeK6O5K6aBtqkulMR-WdHg
# Autores: @soumya_sarkar96, @Free_Palestine_from_israel
# URLs de Channel: http://www.youtube.com/@Free_Palestine_from_israel, http://www.youtube.com/@soumya_sarkar96
#
# Author Channel ID: UCehFjpv7DFUXP0gY3EJNFEQ
# Autores: @Benzene_42, @Santani_world_4u
# URLs de Channel: http://www.youtube.com/@Santani_world_4u, http://www.youtube.com/@Benzene_42
#
# Author Channel ID: UCfDI2W7J2PU51YUoLZTpcIg
# Autores: @FatherFractal, @intolerableHistories
# URLs de Channel: http://www.youtube.com/@FatherFractal, http://www.youtube.com/@intolerableHistories
#
# Author Channel ID: UCfEfWk3lvWgnK-PnyHxHy7g
# Autores: @SalehSingh33, @SalehAthwal99
# URLs de Channel: http://www.youtube.com/@SalehSingh33, http://www.youtube.com/@SalehAthwal99
#
# Author Channel ID: UCgfgqfV3PDPlat4P_lUU4Dw
# Autores: @KirksCORNER-1983, @KirksCORNER1983
# URLs de Channel: http://www.youtube.com/@KirksCORNER-1983, http://www.youtube.com/@KirksCORNER1983
#
# Author Channel ID: UChAqoudKp68m-hAV7wqZrgQ
# Autores: @Pioneers-f4g, @sarveshbhatt2859
# URLs de Channel: http://www.youtube.com/@Pioneers-f4g, http://www.youtube.com/@sarveshbhatt2859
#
# Author Channel ID: UChIzQx37V_KvW7UmO69rzyA
# Autores: @Bannedfakemedia, @Given_Freeman8
# URLs de Channel: http://www.youtube.com/@Given_Freeman8, http://www.youtube.com/@Bannedfakemedia
#
# Author Channel ID: UChREy8Smo8JXQOxxKhj89Aw
# Autores: @onlinethehealingclub, @freehealeronline, @abbhnews
# URLs de Channel: http://www.youtube.com/@onlinethehealingclub, http://www.youtube.com/@freehealeronline, http://www.youtube.com/@abbhnews
#
# Author Channel ID: UCi8YDSkGOHBmHubLD3j-Eyg
# Autores: @Pashazeco, @Fareeddelsooz
# URLs de Channel: http://www.youtube.com/@Fareeddelsooz, http://www.youtube.com/@Pashazeco
#
# Author Channel ID: UCiJV1LzBi_NYToUQBD0fisw
# Autores: @TomWhite-y4k, @caught-c9w
# URLs de Channel: http://www.youtube.com/@TomWhite-y4k, http://www.youtube.com/@caught-c9w
#
# Author Channel ID: UCiSK1_yhlPqaaLNFYCJHv1Q
# Autores: @MiamiFloridaAntiZionist, @gAIPACisAntiFreedomUSA, @IsraelKillsKids
# URLs de Channel: http://www.youtube.com/@gAIPACisAntiFreedomUSA, http://www.youtube.com/@MiamiFloridaAntiZionist, http://www.youtube.com/@IsraelKillsKids
#
# Author Channel ID: UCiSNf3OpEp4iB9CGW69BlUQ
# Autores: @Native_soul321, @ASHKE-NATZI
# URLs de Channel: http://www.youtube.com/@ASHKE-NATZI, http://www.youtube.com/@Native_soul321
#
# Author Channel ID: UCiT1aix7q3K3XN3VVgl92xw
# Autores: @BOSE______THE_ENDLESS, @Singhraur-tr1hq
# URLs de Channel: http://www.youtube.com/@Singhraur-tr1hq, http://www.youtube.com/@BOSE______THE_ENDLESS
#
# Author Channel ID: UCi_9hd8DxbewI6svpQlOKRw
# Autores: @lins3082, @KRAKEN777-u7b
# URLs de Channel: http://www.youtube.com/@KRAKEN777-u7b, http://www.youtube.com/@lins3082
#
# Author Channel ID: UCjMBR4r7Nk8LDXdDbByhTag
# Autores: @Senseless_lines, @Mr.fxan.
# URLs de Channel: http://www.youtube.com/@Mr.fxan., http://www.youtube.com/@Senseless_lines
#
# Author Channel ID: UCk1qXd5bf3QeOrGGgHfTvbg
# Autores: @CaptainGoodguySentientAI, @Muttenchopsforever
# URLs de Channel: http://www.youtube.com/@Muttenchopsforever, http://www.youtube.com/@CaptainGoodguySentientAI
#
# Author Channel ID: UCkM7mxYsMCP9imPo5xFTlKg
# Autores: @Akoejongma, @Daruwang
# URLs de Channel: http://www.youtube.com/@Akoejongma, http://www.youtube.com/@Daruwang
#
# Author Channel ID: UCkQ_wl1lzIgoCGCmSxa2gOg
# Autores: @2019gantiPresiden2, @EseMkagaiB
# URLs de Channel: http://www.youtube.com/@EseMkagaiB, http://www.youtube.com/@2019gantiPresiden2
#
# Author Channel ID: UCkS1W9Zf-j8P4x4PAXkh4Jw
# Autores: @ak_athariyyah, @aksalafi
# URLs de Channel: http://www.youtube.com/@aksalafi, http://www.youtube.com/@ak_athariyyah
#
# Author Channel ID: UCkvywZoW01FGC3iilrz64CQ
# Autores: @JamesHenry-x1f, @Jimz1B
# URLs de Channel: http://www.youtube.com/@JamesHenry-x1f, http://www.youtube.com/@Jimz1B
#
# Author Channel ID: UClDW0MoKUtD-jYKsIgjX5JA
# Autores: @parusha22, @parusha33
# URLs de Channel: http://www.youtube.com/@parusha22, http://www.youtube.com/@parusha33
#
# Author Channel ID: UCldtGz5mE4si67jIyh8sFCQ
# Autores: @dot0422, @SupremeCorine
# URLs de Channel: http://www.youtube.com/@dot0422, http://www.youtube.com/@SupremeCorine
#
# Author Channel ID: UCm2saYB52kCnXWG06kqdiqg
# Autores: @Blissfullydull, @Walterwhite9798
# URLs de Channel: http://www.youtube.com/@Walterwhite9798, http://www.youtube.com/@Blissfullydull
#
# Author Channel ID: UCmDgyByYMivEp8uBEDaOF3g
# Autores: @MuhammadFaridsb6xb, @PoliticalWorldsb6xb
# URLs de Channel: http://www.youtube.com/@MuhammadFaridsb6xb, http://www.youtube.com/@PoliticalWorldsb6xb
#
# Author Channel ID: UCmZsStMOBhU5ai7Lh2Vod6A
# Autores: @salehkibria4724, @SKibria1963
# URLs de Channel: http://www.youtube.com/@SKibria1963, http://www.youtube.com/@salehkibria4724
#
# Author Channel ID: UCn5EYh4_eJve-uNCIuHRKqw
# Autores: @pojaonworld888, @pojaonworld6339
# URLs de Channel: http://www.youtube.com/@pojaonworld6339, http://www.youtube.com/@pojaonworld888
#
# Author Channel ID: UCnEuDT2MO42tqXxwpopUD1g
# Autores: @JustinCase010q, @DreFelton-s3q
# URLs de Channel: http://www.youtube.com/@JustinCase010q, http://www.youtube.com/@DreFelton-s3q
#
# Author Channel ID: UCnHFQyhZ1RtYf2wv66tv7Gg
# Autores: @FudgethePudge, @Doogle999
# URLs de Channel: http://www.youtube.com/@Doogle999, http://www.youtube.com/@FudgethePudge
#
# Author Channel ID: UCnqokZUQuXBxqTX57BW8O6A
# Autores: @srikantsubramanian4886, @Umesh12121
# URLs de Channel: http://www.youtube.com/@Umesh12121, http://www.youtube.com/@srikantsubramanian4886
#
# Author Channel ID: UCo2nk1N2EeIMwcEjRnFmLRQ
# Autores: @progressthroughpain, @inner_iron
# URLs de Channel: http://www.youtube.com/@inner_iron, http://www.youtube.com/@progressthroughpain
#
# Author Channel ID: UCoCnUxxakEsc0Ry-cc1AUpw
# Autores: @keevvvd9197, @keevd1
# URLs de Channel: http://www.youtube.com/@keevvvd9197, http://www.youtube.com/@keevd1
#
# Author Channel ID: UCoumXsLGmWXzbHnk4J0S1dg
# Autores: @InvisibleEnergy-sy3ud, @THORSLANDS
# URLs de Channel: http://www.youtube.com/@THORSLANDS, http://www.youtube.com/@InvisibleEnergy-sy3ud
#
# Author Channel ID: UCoyo8KxEp_F6R6oHT3dXPMQ
# Autores: @watermelon_disneytoons, @PeaceThruStrength-xyz
# URLs de Channel: http://www.youtube.com/@PeaceThruStrength-xyz, http://www.youtube.com/@watermelon_disneytoons
#
# Author Channel ID: UCpBadEPzm5mMr9asYCRKmQA
# Autores: @P_Dbln, @NewHandle_
# URLs de Channel: http://www.youtube.com/@P_Dbln, http://www.youtube.com/@NewHandle_
#
# Author Channel ID: UCpVLE6z9r5Y_G8vu4W4FXyw
# Autores: @Elad__1, @DistortedBirth
# URLs de Channel: http://www.youtube.com/@DistortedBirth, http://www.youtube.com/@Elad__1
#
# Author Channel ID: UCpYqT-Jtez7oNlnizDBTvyQ
# Autores: @Letstalktruthfam, @annusaannspiration9197
# URLs de Channel: http://www.youtube.com/@annusaannspiration9197, http://www.youtube.com/@Letstalktruthfam
#
# Author Channel ID: UCpdq2KrJRZwMNOqUd1pkvtQ
# Autores: @MF_Plissken, @_robespierre
# URLs de Channel: http://www.youtube.com/@MF_Plissken, http://www.youtube.com/@_robespierre
#
# Author Channel ID: UCpzg-dwmOgHwp9pRoeOdQow
# Autores: @zinswe4469, @yakirabatya
# URLs de Channel: http://www.youtube.com/@yakirabatya, http://www.youtube.com/@zinswe4469
#
# Author Channel ID: UCq0l0QuVrECqE-H9MeBDB5g
# Autores: @feeb812, @camille155
# URLs de Channel: http://www.youtube.com/@feeb812, http://www.youtube.com/@camille155
#
# Author Channel ID: UCqCv5WnskONw3opGUNrW9eg
# Autores: @masonsimms9172, @mason_simms
# URLs de Channel: http://www.youtube.com/@mason_simms, http://www.youtube.com/@masonsimms9172
#
# Author Channel ID: UCqPkgwL9qp2OqaeMBE2QZsg
# Autores: @CaptainNegative-x7s, @PeaceMaker669-c1i
# URLs de Channel: http://www.youtube.com/@CaptainNegative-x7s, http://www.youtube.com/@PeaceMaker669-c1i
#
# Author Channel ID: UCruhdXfOHPdFRiNXoXprxQQ
# Autores: @Lawrence_Bishnoi_sher, @Aayein_YaYaYa
# URLs de Channel: http://www.youtube.com/@Aayein_YaYaYa, http://www.youtube.com/@Lawrence_Bishnoi_sher
#
# Author Channel ID: UCsDcD06ayokGckFFPiPSODw
# Autores: @Urlocalgrandmaa, @99trees
# URLs de Channel: http://www.youtube.com/@99trees, http://www.youtube.com/@Urlocalgrandmaa
#
# Author Channel ID: UCsYzkq4D6mSNc6N89L1RyBg
# Autores: @Pixelarousal, @benstillerfan42069
# URLs de Channel: http://www.youtube.com/@benstillerfan42069, http://www.youtube.com/@Pixelarousal
#
# Author Channel ID: UCswOy7bbV1_FKGHeoNcm11w
# Autores: @SCORPIMizrahi, @SCORPiIO455
# URLs de Channel: http://www.youtube.com/@SCORPiIO455, http://www.youtube.com/@SCORPIMizrahi
#
# Author Channel ID: UCtHCwaFFG2BXjKSrVQX-xlQ
# Autores: @dougsisk-c9l, @Real-Joey-Merlino
# URLs de Channel: http://www.youtube.com/@dougsisk-c9l, http://www.youtube.com/@Real-Joey-Merlino
#
# Author Channel ID: UCtXe3QlHDi7F-ojBR9BxjQg
# Autores: @MrArtist7777, @RussellFineArt
# URLs de Channel: http://www.youtube.com/@MrArtist7777, http://www.youtube.com/@RussellFineArt
#
# Author Channel ID: UCtYv6es4cpsg_A2ZQ3an5ow
# Autores: @ice8531, @handle8431
# URLs de Channel: http://www.youtube.com/@ice8531, http://www.youtube.com/@handle8431
#
# Author Channel ID: UCuC-FAK6TJseBAhj9ynT_Rw
# Autores: @CatNat1974, @exoticgirl1
# URLs de Channel: http://www.youtube.com/@CatNat1974, http://www.youtube.com/@exoticgirl1
#
# Author Channel ID: UCuEHmVL9iQ8E4WcXFmHQpRQ
# Autores: @DupeeUduak, @WinnerAlways-n5v
# URLs de Channel: http://www.youtube.com/@DupeeUduak, http://www.youtube.com/@WinnerAlways-n5v
#
# Author Channel ID: UCuY15Y4MLL749S8D4_ZJoaA
# Autores: @RadOn60FPS, @RadostinMarinov24
# URLs de Channel: http://www.youtube.com/@RadostinMarinov24, http://www.youtube.com/@RadOn60FPS
#
# Author Channel ID: UCujBDH4nbQ4NSK5MAbPhYiA
# Autores: @MangoMousse888, @SatayKebab
# URLs de Channel: http://www.youtube.com/@MangoMousse888, http://www.youtube.com/@SatayKebab
#
# Author Channel ID: UCuk_7ezb6t4qivLKWbqpcrw
# Autores: @303soma, @Psycoopa
# URLs de Channel: http://www.youtube.com/@303soma, http://www.youtube.com/@Psycoopa
#
# Author Channel ID: UCvTwiAQHOJ8taa4dEpGW4GA
# Autores: @Fo-real-one, @wali369
# URLs de Channel: http://www.youtube.com/@Fo-real-one, http://www.youtube.com/@wali369
#
# Author Channel ID: UCvsC7FMHOG_05VtFWo2aY8g
# Autores: @MK-pt9xt, @M-pt9xt
# URLs de Channel: http://www.youtube.com/@MK-pt9xt, http://www.youtube.com/@M-pt9xt
#
# Author Channel ID: UCvxdbqUNdQU1tr6A53Pw2kQ
# Autores: @Darealmookster, @BrutallyMook
# URLs de Channel: http://www.youtube.com/@BrutallyMook, http://www.youtube.com/@Darealmookster
#
# Author Channel ID: UCw9pyAfkqanHa0y8eauuqCQ
# Autores: @EveryHotGirlsDaddy, @Hokomakachi
# URLs de Channel: http://www.youtube.com/@Hokomakachi, http://www.youtube.com/@EveryHotGirlsDaddy
#
# Author Channel ID: UCwZyCIH3M6MxDwaDwPjslBQ
# Autores: @Iguf5ctub6f, @6uf7dtdy
# URLs de Channel: http://www.youtube.com/@6uf7dtdy, http://www.youtube.com/@Iguf5ctub6f
#
# Author Channel ID: UCw_Lnd3i-zxco9tlswBU0YQ
# Autores: @Lucyinthesky098, @Pandorasboxnooooo
# URLs de Channel: http://www.youtube.com/@Pandorasboxnooooo, http://www.youtube.com/@Lucyinthesky098
#
# Author Channel ID: UCwask51co9PIL0rnAEeqWSA
# Autores: @Mexg2dg, @MartinKinsella-xg2dg
# URLs de Channel: http://www.youtube.com/@MartinKinsella-xg2dg, http://www.youtube.com/@Mexg2dg
#
# Author Channel ID: UCx2-IBPG7KvWWuOTSN24Uiw
# Autores: @007BASUDEV, @123KCKS
# URLs de Channel: http://www.youtube.com/@123KCKS, http://www.youtube.com/@007BASUDEV
#
# Author Channel ID: UCx7xVuHQw_xOxbXqrTdrwAQ
# Autores: @Vincentvega293, @glencecil293
# URLs de Channel: http://www.youtube.com/@Vincentvega293, http://www.youtube.com/@glencecil293
#
# Author Channel ID: UCy3RPUlhmQszL941cMeZhVA
# Autores: @GREPREP-w6k, @Real_man67-q6w
# URLs de Channel: http://www.youtube.com/@GREPREP-w6k, http://www.youtube.com/@Real_man67-q6w
#
# Author Channel ID: UCyGQ2JLI9TmiAwco6Cxw_lA
# Autores: @harleyx7332, @Shadowdash66X
# URLs de Channel: http://www.youtube.com/@Shadowdash66X, http://www.youtube.com/@harleyx7332
#
# Author Channel ID: UCyd_V322s_pimUplEizsItw
# Autores: @Cavillrine36, @Harshgupta3po
# URLs de Channel: http://www.youtube.com/@Cavillrine36, http://www.youtube.com/@Harshgupta3po
#
# Author Channel ID: UCyjg7DbWxYtSsGXBb8-NuSg
# Autores: @Sdgter, @Phantom-o6j
# URLs de Channel: http://www.youtube.com/@Phantom-o6j, http://www.youtube.com/@Sdgter
#
# Author Channel ID: UCyteb9PI9R7_ucdwqm18q2Q
# Autores: @Hindu-n3h, @Tommy1008-d3q
# URLs de Channel: http://www.youtube.com/@Hindu-n3h, http://www.youtube.com/@Tommy1008-d3q
#
# Author Channel ID: UCyv24L7Zqak_anzouM6QbGw
# Autores: @Decode-tech-i, @One-Budget
# URLs de Channel: http://www.youtube.com/@Decode-tech-i, http://www.youtube.com/@One-Budget
#
# Author Channel ID: UCz0kpq6zH2CJkNC9emrMSkQ
# Autores: @Nuroshahiro, @abukabaab
# URLs de Channel: http://www.youtube.com/@Nuroshahiro, http://www.youtube.com/@abukabaab
#
# Author Channel ID: UCz3v6DC_e0sAvv529HAIdCg
# Autores: @Nails-w23, @NailsandDesigner
# URLs de Channel: http://www.youtube.com/@NailsandDesigner, http://www.youtube.com/@Nails-w23
#
# Author Channel ID: UCzEd4w04mbZciaWtrKX6ROA
# Autores: @MyPrettyPinkCameltoe, @TheRockIslandRock
# URLs de Channel: http://www.youtube.com/@MyPrettyPinkCameltoe, http://www.youtube.com/@TheRockIslandRock
#
# Author Channel ID: UCzJ_36cKQU_GW23ZLejBC5Q
# Autores: @Appwuggsamiarivddrsamy, @Appusamiarivrsamyhiolowsyel
# URLs de Channel: http://www.youtube.com/@Appwuggsamiarivddrsamy, http://www.youtube.com/@Appusamiarivrsamyhiolowsyel
#
# Author Channel ID: UCzNKLu5Fsamkd03EOX1Gviw
# Autores: @mona00941, @KK99-r2t
# URLs de Channel: http://www.youtube.com/@KK99-r2t, http://www.youtube.com/@mona00941
#
# Author Channel ID: UCzbapVVA0_r7nEwQkWIlt7g
# Autores: @Khan-x9y-z6i, @Niaz-333N
# URLs de Channel: http://www.youtube.com/@Khan-x9y-z6i, http://www.youtube.com/@Niaz-333N
#
# Author Channel ID: UCzkMRtWaMPJ0TNbKmsHQt5Q
# Autores: @Abednego_1, @AbednegoBedinkonim-sd8cc
# URLs de Channel: http://www.youtube.com/@AbednegoBedinkonim-sd8cc, http://www.youtube.com/@Abednego_1
#
# Author Channel ID: UCznPN_2_2v5B3sqkelkNRTg
# Autores: @rafaelfernandez1194, @rafa-el2020
# URLs de Channel: http://www.youtube.com/@rafaelfernandez1194, http://www.youtube.com/@rafa-el2020

# %%
# Remover registros com author_channel_id ou comment_id nulos
palestine_df_coments = palestine_df_comments.dropna(subset=['author_channel_id', 'comment_id'])

# %%
## Estatísticas Atualizadas

# df1 e df2 são os seus DataFrames de entrada
columns = ['comment_id', 'author_channel_id', 'author', 'author_channel_url', 'video_id', 'channel_id']
resultado_comparacao = compare_dataframes(original_comments, palestine_df_comments, columns)

# Exibindo os resultados
print("=== Valores Não Nulos ===")
print(resultado_comparacao["Valores Não Nulos"])

print("\n=== Valores Nulos ===")
print(resultado_comparacao["Valores Nulos"])

print("\n=== Valores Únicos ===")
print(resultado_comparacao["Valores Únicos"])
# Out:
# === Valores Não Nulos ===
#                Coluna  Original  Após Tratamento  Diferença
# 0          comment_id    814975           717667      97308
# 1   author_channel_id    814975           717667      97308
# 2              author    814303           717041      97262
# 3  author_channel_url    814975           717667      97308
# 4            video_id    814975           717667      97308
# 5          channel_id    814975           717667      97308
#
# === Valores Nulos ===
#                Coluna  Original  Após Tratamento  Diferença
# 0          comment_id         0                0          0
# 1   author_channel_id         0                0          0
# 2              author       672              626         46
# 3  author_channel_url         0                0          0
# 4            video_id         0                0          0
# 5          channel_id         0                0          0
#
# === Valores Únicos ===
#                Coluna  Original  Após Tratamento  Diferença
# 0          comment_id    814584           717667      96917
# 1   author_channel_id    361225           320366      40859
# 2              author    361247           320371      40876
# 3  author_channel_url    361459           320569      40890
# 4            video_id       811              805          6
# 5          channel_id       221              217          4

# %%
palestine_df_comments
# Out:
#            video_id                                         comment_id  \
# 789472  XQGoaVvpm-c                         UgyDIMGydtCmgB41-SN4AaABAg
# 789473  XQGoaVvpm-c                         UgxUGpdHzAceyYbIWDN4AaABAg
# 789474  XQGoaVvpm-c                         UgyPfhLChrSMH0hSopR4AaABAg
# 789475  XQGoaVvpm-c                         UgzcyIzP8x-MpOea_7V4AaABAg
# 759573  rGpYoVsCTdg  UgxUNu91s5_4wWdEJ4h4AaABAg.A8xFzWWQ0MSAAGvsgmW2l1
# ...             ...                                                ...
# 689599  rvlQIo60tV4                         UgzaDFIViC98wmEqEdR4AaABAg
# 689600  rvlQIo60tV4                         Ugw2Jtx0n6qufNR4zQJ4AaABAg
# 689601  rvlQIo60tV4                         UgyHaEtt528FzLJe_6J4AaABAg
# 689602  rvlQIo60tV4                         UgzrRIcuLYaO8BfdeM54AaABAg
# 689603  rvlQIo60tV4                         UgxLKgbvmmwQxoNj3WF4AaABAg
#
#                             author  \
# 789472             @LinguaFonetica
# 789473               @dsnitzer7123
# 789474                @bravoRFId63
# 789475              @mirhaider8190
# 759573          @SonaharKhatun-o4y
# ...                            ...
# 689599    @notruthinthisworld.8414
# 689600                      @rx1-x
# 689601                  @semprince
# 689602  @franciscahammerschlag4103
# 689603         @nicholashughes8214
#
#                                  author_profile_image_url  \
# 789472  https://yt3.ggpht.com/rInZmo_JEgl4nulr_4CGI3AX...
# 789473  https://yt3.ggpht.com/ytc/AIdro_nbnAzz17y0AjU8...
# 789474  https://yt3.ggpht.com/ej1GuFl15ApadgYd_7yxo5tJ...
# 789475  https://yt3.ggpht.com/ytc/AIdro_nbh-GLc1yW_xPy...
# 759573  https://yt3.ggpht.com/ytc/AIdro_mGCcO77qRAILee...
# ...                                                   ...
# 689599  https://yt3.ggpht.com/ytc/AIdro_nGeYh4-7xWgW6D...
# 689600  https://yt3.ggpht.com/DVNqhaFcJZ-MwLeOlStzCEYn...
# 689601  https://yt3.ggpht.com/ytc/AIdro_nlK0XZCHPihWVQ...
# 689602  https://yt3.ggpht.com/ytc/AIdro_lMN55rIWAdDHgN...
# 689603  https://yt3.ggpht.com/ytc/AIdro_mAdcE4vRvBuqmF...
#
#                                        author_channel_url  \
# 789472             http://www.youtube.com/@LinguaFonetica
# 789473               http://www.youtube.com/@dsnitzer7123
# 789474                http://www.youtube.com/@bravoRFId63
# 789475              http://www.youtube.com/@mirhaider8190
# 759573          http://www.youtube.com/@SonaharKhatun-o4y
# ...                                                   ...
# 689599    http://www.youtube.com/@notruthinthisworld.8414
# 689600                      http://www.youtube.com/@rx1-x
# 689601                  http://www.youtube.com/@semprince
# 689602  http://www.youtube.com/@franciscahammerschlag4103
# 689603         http://www.youtube.com/@nicholashughes8214
#
#                author_channel_id  \
# 789472  UCAwi3tah_hWiJeJkLb2DJbw
# 789473  UCshMbwtdRAS8CnQVBoSk93w
# 789474  UChdq_Q1KPuIoN5GjvRA-Ssw
# 789475  UCxd5mGTlssjH4Vlt33wq2gw
# 759573  UCZ9loIfErRtAaXFa0ofxgNQ
# ...                          ...
# 689599  UCEzey9OLufC3Li0Q0ZmK1yQ
# 689600  UCbJOpUIYAWZmt9kD0wbuxRw
# 689601  UCAxYnY_CrgVYP5-jkRe4GqQ
# 689602  UCJ7CKcM1i6myQfVL8pY7Wkw
# 689603  UC5LRx5fEJu5grnG3UJRSL4Q
#
#                                                   comment  \
# 789472  said un resolution justifies jewish state arab...
# 789473  cease fire deallebanoniran syriarussiaedomanyo...
# 789474                                           say math
# 789475                   nice try b palestine stolen land
# 759573  mmdi whyjust telling truthdo humanitythe whole...
# ...                                                   ...
# 689599                                  oops bad news idf
# 689600  repeat lie often enough eventually becomes israel
# 689601                                   fool making fool
# 689602  lie told idf tunnel gaza tunnel yet discovered...
# 689603  ohh mean idf israeli government lied way youll...
#
#                 published_at            updated_at  like_count viewer_rating  \
# 789472  2024-10-31T23:13:50Z  2024-10-31T23:13:50Z           0          none
# 789473  2024-10-31T22:28:58Z  2024-10-31T22:28:58Z           0          none
# 789474  2024-10-31T22:15:26Z  2024-10-31T22:15:26Z           0          none
# 789475  2024-10-31T22:13:54Z  2024-10-31T22:13:54Z           0          none
# 759573  2024-10-31T21:23:24Z  2024-10-31T21:23:24Z           0          none
# ...                      ...                   ...         ...           ...
# 689599  2024-09-15T05:23:58Z  2024-09-15T05:23:58Z          67          none
# 689600  2024-09-15T05:22:11Z  2024-09-15T05:22:11Z         656          none
# 689601  2024-09-15T05:21:24Z  2024-09-15T05:21:24Z         177          none
# 689602  2024-09-15T05:16:48Z  2024-09-15T05:16:48Z           4          none
# 689603  2024-09-15T05:06:35Z  2024-09-15T05:06:35Z           0          none
#
#         can_rate  is_reply                   parent_id  \
# 789472      True     False                         NaN
# 789473      True     False                         NaN
# 789474      True     False                         NaN
# 789475      True     False                         NaN
# 759573      True      True  UgxUNu91s5_4wWdEJ4h4AaABAg
# ...          ...       ...                         ...
# 689599      True     False                         NaN
# 689600      True     False                         NaN
# 689601      True     False                         NaN
# 689602      True     False                         NaN
# 689603      True     False                         NaN
#
#                       channel_id     language urls mentions
# 789472  UC1EasxeXGzoXJb2y3HTMsLA  __label__en   []       []
# 789473  UC1EasxeXGzoXJb2y3HTMsLA  __label__en   []       []
# 789474  UC1EasxeXGzoXJb2y3HTMsLA  __label__en   []       []
# 789475  UC1EasxeXGzoXJb2y3HTMsLA  __label__en   []       []
# 759573  UCmTM_hPCeckqN3cPWtYZZcg  __label__en   []  [@Akna]
# ...                          ...          ...  ...      ...
# 689599  UCm7lHFkt2yB_WzL67aruVBQ  __label__en   []       []
# 689600  UCm7lHFkt2yB_WzL67aruVBQ  __label__en   []       []
# 689601  UCm7lHFkt2yB_WzL67aruVBQ  __label__en   []       []
# 689602  UCm7lHFkt2yB_WzL67aruVBQ  __label__en   []       []
# 689603  UCm7lHFkt2yB_WzL67aruVBQ  __label__en   []       []
#
# [717667 rows x 18 columns]

# %% [markdown]
# # Exportação de Dados

# %%
palestine_df_comments.to_csv('{bp}/{country}/{country}_finalData.csv'.format(bp=base_path, country=country), encoding='utf-8')
df_videos.to_csv('{bp}/{country}/{country}_videos_finalData.csv'.format(bp=base_path, country=country), encoding='utf-8')
df_channels.to_csv('{bp}/{country}/{country}_channels_finalData.csv'.format(bp=base_path, country=country), encoding='utf-8')
