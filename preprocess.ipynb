# %% [markdown]
# # Israel x World
#
# **Discente**: Victor Hugo Martins
#
# **Orientadora**: Jussara Almeida
#
# ## Objetivo Geral
# Descrever os dados coletados sobre os vídeos postados entre 01/10/24 a 31/10 com foco nos conflitos ocorridos entre Israel e Palestina.

# %% [markdown]
# ## Preparação de Dados

# %%
import pandas as pd
import os

def read_csv_batches_from_dir(directory):
    all_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.csv')]
    df_list = []

    for file in all_files:
        print(f"Lendo arquivo: {file}")
        df = pd.read_csv(file)
        df_list.append(df)

    # Concatenar todos os DataFrames em um só
    final_df = pd.concat(df_list, ignore_index=True)
    return final_df

def import_data(country):
  # Caminho base no Google Drive

  # Diretórios contendo os arquivos CSV de comentários, vídeos e canais
  comments_dir = os.path.join(base_path, '{country}/comments_csv_batches'.format(country=country))
  videos_dir = os.path.join(base_path, '{country}/videos_csv_batches'.format(country=country))
  channels_dir = os.path.join(base_path, '{country}/channels_csv_batches'.format(country=country))

  # Ler todos os arquivos CSV dos diretórios
  df_comments = read_csv_batches_from_dir(comments_dir)
  df_videos = read_csv_batches_from_dir(videos_dir)
  df_channels = read_csv_batches_from_dir(channels_dir)

  return df_comments, df_videos, df_channels

palestine_df_comments, df_videos, df_channels = import_data('palestine')
# Out:
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_1.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_4.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_5.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_2.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_3.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_7.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_6.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_8.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_11.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_12.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_9.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_10.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_14.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_15.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_13.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_16.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_19.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_18.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_17.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_21.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_23.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_20.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_22.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_24.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_25.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_26.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_30.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_27.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_29.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_28.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_33.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_31.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_32.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_34.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_36.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_35.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_39.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_38.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_37.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_41.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_42.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_40.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_44.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_45.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_43.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_48.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_46.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_47.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_50.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_49.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_51.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_52.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_53.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_54.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_55.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_56.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_58.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_57.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_59.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_61.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_60.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_64.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_62.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_63.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_66.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_65.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_67.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_68.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_69.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_71.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_72.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_70.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_73.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_74.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_76.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_75.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_77.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_80.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_79.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_78.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_81.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/comments_csv_batches/lote_82.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/videos_csv_batches/lote_1.csv
# Lendo arquivo: /content/drive/My Drive/Mestrado/palestine/channels_csv_batches/lote_1.csv

# %% [markdown]
# ### Comments

# %%
palestine_df_comments
# Out:
#            video_id                                         comment_id  \
# 0       rai_sj91Mts  Ugw9jGAzIj7ZEd3ctsJ4AaABAg.A9SXu5XETuNA9_YDq1UL2d
# 1       KnIUzxhDLXQ                         UgzipCDxCGKZdbENemV4AaABAg
# 2       rai_sj91Mts  Ugw9jGAzIj7ZEd3ctsJ4AaABAg.A9SXu5XETuNA9_XoU4LceB
# 3       lYXzMnN7SFg                         UgzQrdFWVWfAQ8zcU3B4AaABAg
# 4       IpA8TU9brro  Ugz3S4TxqoQMvXcJ4aZ4AaABAg.A9WTlNPItFlA9_XLKZ1W5O
# ...             ...                                                ...
# 814970  d8AP7rQvV6Y                         Ugw51FdhTUWk9lGjRTd4AaABAg
# 814971  d8AP7rQvV6Y                         UgwNzQ7P-35_ZPkw-MZ4AaABAg
# 814972  d8AP7rQvV6Y                         UgyFeWKQDfg6KgAOorx4AaABAg
# 814973  d8AP7rQvV6Y                         Ugyi8qwzcz7Ktvg42A94AaABAg
# 814974  d8AP7rQvV6Y                         Ugy6qZn-K_pSYHQOeDR4AaABAg
#
#                      author  \
# 0       @ehitaredestiny3146
# 1               @darwisojol
# 2                 @1nadiald
# 3            @andrysabatini
# 4                @1312Mork2
# ...                     ...
# 814970    @faizahfaizah8255
# 814971    @lukmanjourney641
# 814972           @Saskoloep
# 814973    @faizalarffin2482
# 814974  @HamjahHamjah-zf8ss
#
#                                  author_profile_image_url  \
# 0       https://yt3.ggpht.com/DE8gbtNTtEb2oI-PKjR2Gw6k...
# 1       https://yt3.ggpht.com/ytc/AIdro_njGmxKfoPrBMaI...
# 2       https://yt3.ggpht.com/ytc/AIdro_nAc7gln-BI6Q9p...
# 3       https://yt3.ggpht.com/6x1qe70o20YWrVdsYCEfDWfy...
# 4       https://yt3.ggpht.com/oSPCnt4WtvcVNqVW4Zvcty5q...
# ...                                                   ...
# 814970  https://yt3.ggpht.com/ytc/AIdro_nFJwocGV8DNqOb...
# 814971  https://yt3.ggpht.com/KLiMwgezEoPzLeuspnu2mMm_...
# 814972  https://yt3.ggpht.com/ytc/AIdro_n-ipYGNyWfz12O...
# 814973  https://yt3.ggpht.com/ytc/AIdro_kdKHEaF6TdB4sb...
# 814974  https://yt3.ggpht.com/ytc/AIdro_npcUR6XsdtEyWk...
#
#                                 author_channel_url         author_channel_id  \
# 0       http://www.youtube.com/@ehitaredestiny3146  UCqC4Hff0ccqdyW9bIQzGSXQ
# 1               http://www.youtube.com/@darwisojol  UCSlryZdcLthIgB_uYpTgEUA
# 2                 http://www.youtube.com/@1nadiald  UCQxFdS-yyMmdd5LnXRG-FoQ
# 3            http://www.youtube.com/@andrysabatini  UC-LNuL326djA50s-0PRq1Lw
# 4                http://www.youtube.com/@1312Mork2  UC6VNPUQL3ltQsJ8bUfRswiQ
# ...                                            ...                       ...
# 814970    http://www.youtube.com/@faizahfaizah8255  UC3XRFOdxYT0MHUaINaosDww
# 814971    http://www.youtube.com/@lukmanjourney641  UCn3ZkgKF-r_QYzp8RiLCETQ
# 814972           http://www.youtube.com/@Saskoloep  UCRRCgLlbKDst9fFjEpfRP_A
# 814973    http://www.youtube.com/@faizalarffin2482  UCsgog3YohGNKrJOhD78RpUQ
# 814974  http://www.youtube.com/@HamjahHamjah-zf8ss  UCp_WABcAVHu7-A0UMPktPuQ
#
#                                                   comment  \
# 0       @@1nadiald what a beautiful liar! Maybe y’all ...
# 1                                                  😂😂😂😂😂😂
# 2                                      What a Dumas take!
# 3                           uomo dispensatore di morte...
# 4                    You need to stop doing thought crime
# ...                                                   ...
# 814970           Ber arti udah mulai jatuh alhamdulillah😊
# 814971  Pertanda idf sudah mau punah dihajar hamas mak...
# 814972  Strategi jitu, kalau tidak mau dikembalikan ke...
# 814973  Tak payah lah Nak menipu lagi, lagipun negara ...
# 814974                Jangan ikut bergabung dengan Israel
#
#                 published_at            updated_at  like_count viewer_rating  \
# 0       2024-10-14T15:41:23Z  2024-10-14T15:41:23Z           0          none
# 1       2024-10-14T15:38:25Z  2024-10-14T15:38:25Z           0          none
# 2       2024-10-14T15:37:47Z  2024-10-14T15:37:47Z           0          none
# 3       2024-10-14T15:35:50Z  2024-10-14T15:35:50Z           0          none
# 4       2024-10-14T15:33:40Z  2024-10-14T15:33:40Z           0          none
# ...                      ...                   ...         ...           ...
# 814970  2024-09-17T05:54:33Z  2024-09-17T05:54:33Z         128          none
# 814971  2024-09-17T05:53:14Z  2024-09-17T05:53:14Z         149          none
# 814972  2024-09-17T05:45:38Z  2024-09-17T05:45:38Z          11          none
# 814973  2024-09-17T05:43:54Z  2024-09-17T05:43:54Z           0          none
# 814974  2024-09-17T05:33:00Z  2024-09-17T05:33:00Z           0          none
#
#         can_rate  is_reply                   parent_id  \
# 0           True      True  Ugw9jGAzIj7ZEd3ctsJ4AaABAg
# 1           True     False                         NaN
# 2           True      True  Ugw9jGAzIj7ZEd3ctsJ4AaABAg
# 3           True     False                         NaN
# 4           True      True  Ugz3S4TxqoQMvXcJ4aZ4AaABAg
# ...          ...       ...                         ...
# 814970      True     False                         NaN
# 814971      True     False                         NaN
# 814972      True     False                         NaN
# 814973      True     False                         NaN
# 814974      True     False                         NaN
#
#                       channel_id
# 0       UCatt7TBjfBkiJWx8khav_Gg
# 1       UC7fWeaHhqgM4Ry-RMpM2YYw
# 2       UCatt7TBjfBkiJWx8khav_Gg
# 3       UCef1-8eOpJgud7szVPlZQAQ
# 4       UCckHqySbfy5FcPP6MD_S-Yg
# ...                          ...
# 814970  UCmxAIW7RDDC88EPk4ry16Kg
# 814971  UCmxAIW7RDDC88EPk4ry16Kg
# 814972  UCmxAIW7RDDC88EPk4ry16Kg
# 814973  UCmxAIW7RDDC88EPk4ry16Kg
# 814974  UCmxAIW7RDDC88EPk4ry16Kg
#
# [814975 rows x 15 columns]

# %%
palestine_df_comments.describe()
# Out:
#           like_count
# count  814975.000000
# mean        6.592394
# std        95.218460
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max     23049.000000

# %% [markdown]
# ### Vídeos

# %%
df_videos
# Out:
#         video_id                                              title  \
# 0    Q_7QIgSANlg  Israeli strike in Aitou in northern Lebanon ki...
# 1    bEzEBz7d1Z8  Israel Vs Hezbollah War LIVE | Inside Israel's...
# 2    tmDjav-5dUI  Israeli air strike destroys historic mosque in...
# 3    NOLJdq4zWFs  Israeli shelling of Gaza school kills at least...
# 4    gTP3ug1DBs0  Israel's brutality towards Palestinians didn’t...
# ..           ...                                                ...
# 806  rGgnRV_Hvw0  ‘Lawless world’ faced by Palestinians in the W...
# 807  a64qJkg2Ac4  Hypersonic Missile Hits Israel | US and Israel...
# 808  oVR7mgvISiA  Gaza Offensive: Israel Recruiting Asylum Seeke...
# 809  N45Kdm-Ue-U  Iran’s 3-Way Proxy War Crushes IDF; Israel Scr...
# 810  rvlQIo60tV4  IDF Shamed By Freed Hostages About Rescue Ops,...
#
#                                            description  \
# 0    The Lebanese Red Cross said 18 people were kil...
# 1    Israel Vs Hezbollah War LIVE | Inside Israel's...
# 2    Israel has destroyed an old mosque in southern...
# 3    An Israeli attack on a school used to shelter ...
# 4    The brutality Israel has been unleashing on Pa...
# ..                                                 ...
# 806  “The fact that I have an Israeli passport and ...
# 807  #Israel #Yemen #Missile #PrashantDhawan #Prash...
# 808  Israel is recruiting African asylum seekers to...
# 809  A fresh report by Israeli media outlet Haaretz...
# 810  Freed Israeli captives spill beans months afte...
#
#                    channel_id          published_at  category_id  \
# 0    UC16niRr50-MSBwiO3YDb3RA  2024-10-14T15:43:19Z           25
# 1    UCef1-8eOpJgud7szVPlZQAQ  2024-10-14T15:34:53Z           25
# 2    UCR0fZh5SBxxMNYdg0VzRFkg  2024-10-14T14:38:56Z           25
# 3    UC16niRr50-MSBwiO3YDb3RA  2024-10-14T14:34:39Z           25
# 4    UC7fWeaHhqgM4Ry-RMpM2YYw  2024-10-14T13:54:43Z           25
# ..                        ...                   ...          ...
# 806  UCR0fZh5SBxxMNYdg0VzRFkg  2024-09-15T14:32:18Z           25
# 807  UCrC8mOqJQpoB7NuIMKIS6rQ  2024-09-15T14:28:00Z           27
# 808  UC_xWTNsx7zA2uI0ydQikViA  2024-09-15T13:40:01Z           25
# 809  UCckHqySbfy5FcPP6MD_S-Yg  2024-09-15T12:10:00Z           25
# 810  UCm7lHFkt2yB_WzL67aruVBQ  2024-09-15T04:56:08Z           25
#
#                                                   tags  view_count  \
# 0    ['bbc', 'bbc news', 'news', 'world news', 'bre...        7860
# 1    ['Israel Vs Hezbollah War', 'Israel Lebanon Wa...        9347
# 2    ['middle east eye', 'mee', 'mee news', 'news',...        7805
# 3    ['bbc', 'bbc news', 'news', 'world news', 'bre...        7076
# 4    ['TRT world', 'trtworld', 'World News', 'break...        3866
# ..                                                 ...         ...
# 806  ['middle east eye', 'mee', 'mee news', 'news',...        7690
# 807  ['Gaza', 'Hamas', 'Houthi attacks on israel', ...     1871962
# 808  ['dawn news english', 'dawn news', 'dawn news ...        1003
# 809  ['times of india', 'toi', 'latest news', 'news...       21121
# 810  ['hindustan times', 'ht media', 'ht news', 'hi...      127810
#
#      like_count  comment_count  ... scheduled_end_time concurrent_viewers  \
# 0           158            113  ...                NaN                  0
# 1            66              3  ...                NaN                  0
# 2          1179            342  ...                NaN                  0
# 3           364            174  ...                NaN                  0
# 4          1391             49  ...                NaN                  0
# ..          ...            ...  ...                ...                ...
# 806         809             73  ...                NaN                  0
# 807       58048           4592  ...                NaN                  0
# 808          19              5  ...                NaN                  0
# 809         281            163  ...                NaN                  0
# 810        2320            745  ...                NaN                  0
#
#      active_live_chat_id  recording_date  \
# 0                    NaN             NaN
# 1                    NaN             NaN
# 2                    NaN             NaN
# 3                    NaN             NaN
# 4                    NaN             NaN
# ..                   ...             ...
# 806                  NaN             NaN
# 807                  NaN             NaN
# 808                  NaN             NaN
# 809                  NaN             NaN
# 810                  NaN             NaN
#
#                                        topicCategories processing_status  \
# 0    ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# 1    ['https://en.wikipedia.org/wiki/Military', 'ht...               NaN
# 2            ['https://en.wikipedia.org/wiki/Society']               NaN
# 3    ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# 4    ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# ..                                                 ...               ...
# 806  ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# 807          ['https://en.wikipedia.org/wiki/Society']               NaN
# 808          ['https://en.wikipedia.org/wiki/Society']               NaN
# 809  ['https://en.wikipedia.org/wiki/Military', 'ht...               NaN
# 810  ['https://en.wikipedia.org/wiki/Military', 'ht...               NaN
#
#      parts_total  parts_processed  time_left_ms processing_failure_reason
# 0              0                0             0                       NaN
# 1              0                0             0                       NaN
# 2              0                0             0                       NaN
# 3              0                0             0                       NaN
# 4              0                0             0                       NaN
# ..           ...              ...           ...                       ...
# 806            0                0             0                       NaN
# 807            0                0             0                       NaN
# 808            0                0             0                       NaN
# 809            0                0             0                       NaN
# 810            0                0             0                       NaN
#
# [811 rows x 35 columns]

# %%
df_videos.describe()
# Out:
#        category_id    view_count     like_count  comment_count  \
# count   811.000000  8.110000e+02     811.000000     811.000000
# mean     24.890259  2.160685e+05    5351.081381    1025.027127
# std       1.803711  4.705475e+05   14116.863401    2457.954095
# min       1.000000  4.000000e+00       0.000000       1.000000
# 25%      25.000000  1.997750e+04     448.500000      99.000000
# 50%      25.000000  6.583500e+04    1563.000000     377.000000
# 75%      25.000000  2.194575e+05    4485.500000    1095.500000
# max      29.000000  6.836883e+06  216578.000000   35712.000000
#
#        scheduled_end_time  concurrent_viewers  active_live_chat_id  \
# count                 0.0               811.0                  0.0
# mean                  NaN                 0.0                  NaN
# std                   NaN                 0.0                  NaN
# min                   NaN                 0.0                  NaN
# 25%                   NaN                 0.0                  NaN
# 50%                   NaN                 0.0                  NaN
# 75%                   NaN                 0.0                  NaN
# max                   NaN                 0.0                  NaN
#
#        processing_status  parts_total  parts_processed  time_left_ms  \
# count                0.0        811.0            811.0         811.0
# mean                 NaN          0.0              0.0           0.0
# std                  NaN          0.0              0.0           0.0
# min                  NaN          0.0              0.0           0.0
# 25%                  NaN          0.0              0.0           0.0
# 50%                  NaN          0.0              0.0           0.0
# 75%                  NaN          0.0              0.0           0.0
# max                  NaN          0.0              0.0           0.0
#
#        processing_failure_reason
# count                        0.0
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN

# %% [markdown]
# ### Canais

# %%
df_channels
# Out:
#                    channel_id                                     title  \
# 0    UC3asD3ORk07XRPGC47hr-0w                              GNC NEWS 360
# 1    UCkmLoDQ8AVKwEsDSJtNKmug                                 WOLD NEWS
# 2    UC1Dlsbku0-iCGc0rXgQpDHQ                            Amaizing Facts
# 3    UC3-n3-ScTQLQ_Gc2tNLJreg  Stakelbeck Tonight with Erick Stakelbeck
# 4    UCF9LFWX5cdGHBg_FDm6tFrQ                           Breezy Politics
# ..                        ...                                       ...
# 216  UCfmSignFWkk1lw4015hCyyQ                               StandWithUs
# 217  UC16niRr50-MSBwiO3YDb3RA                                  BBC News
# 218  UCHpw8xwDNhU9gdohEcJu4aA                              The Guardian
# 219  UCm7lHFkt2yB_WzL67aruVBQ                           Hindustan Times
# 220  UCupvZG-5ko_eiXAupbDfxWw                                       CNN
#
#                                            description  \
# 0    🌍 Welcome to GNC – Global News Channel! 🌍\n\nA...
# 1                                   Subscribe  for USA
# 2    Target Subscribers 1 Million\n\nHello everyone...
# 3    Welcome to the Stakelbeck Tonight with Erick S...
# 4                             Politics By The People.
# ..                                                 ...
# 216  Fighting Antisemitism and Supporting Israel Ar...
# 217  Welcome to the official BBC News YouTube chann...
# 218  The Guardian brings you news, documentaries, a...
# 219  Hindustan Times Videos bring you news, views a...
# 220  CNN is the world leader in news and informatio...
#
#                     published_at country   view_count  comment_count  \
# 0    2024-09-22T02:57:31.675741Z      US         7096              0
# 1    2024-08-31T21:48:41.363607Z      US       372583              0
# 2    2024-06-05T10:37:49.325123Z      PK     84711317              0
# 3    2024-05-03T21:23:42.240192Z      US      2423653              0
# 4    2024-02-24T18:00:09.134775Z      US    101447822              0
# ..                           ...     ...          ...            ...
# 216         2006-06-06T22:44:08Z      IL     44427727              0
# 217         2006-04-08T05:51:05Z      GB   5607586404              0
# 218         2006-02-15T03:22:40Z      GB    729761411              0
# 219         2005-11-16T02:41:16Z      IN   5607879981              0
# 220         2005-10-02T16:06:36Z     NaN  16751878276              0
#
#      subscriber_count  video_count  is_verified  \
# 0                  27           20        False
# 1                 481          275        False
# 2              238000          412        False
# 3               31300           70        False
# 4              206000          575        False
# ..                ...          ...          ...
# 216            192000         1465        False
# 217          16800000        23220        False
# 218           2290000         7250        False
# 219           7370000        69366        False
# 220          17100000       167408        False
#
#                                               keywords  \
# 0                                                  NaN
# 1                  trump noticia "kamalla harris" vote
# 2    short shorts animals viral edits israel palest...
# 3    "erick stakelbeck" "the watchman with erick st...
# 4                                                  NaN
# ..                                                 ...
# 216  standwithus Israel Education activism pro-isra...
# 217                  BBC News Official YouTube Channel
# 218  guardian news film video environment documenta...
# 219  "world news" "us news" "HT world" "Hindustan T...
# 220                CNN "CNN News" news "breaking news"
#
#                                    profile_picture_url
# 0    https://yt3.ggpht.com/rE7KFfBo-a7KVXDR2xtVoESi...
# 1    https://yt3.ggpht.com/VZXxIUrbv9NoSwomQz_4sOlC...
# 2    https://yt3.ggpht.com/dCjKkhHRFEPvorpV1vhdD1XT...
# 3    https://yt3.ggpht.com/Oz0YlzbQAiPwkqA0vH1832AL...
# 4    https://yt3.ggpht.com/I5YmN4cKN0Vaon04Qs9hBbF2...
# ..                                                 ...
# 216  https://yt3.ggpht.com/ytc/AIdro_mh8eN8fDlZehoy...
# 217  https://yt3.ggpht.com/y_esGAQOhX4rTpWvrALErAJl...
# 218  https://yt3.ggpht.com/P7QrZEnioCzOeKA2sWKyxvR5...
# 219  https://yt3.ggpht.com/rxxycwwjFXuC-eQNBcklj4P-...
# 220  https://yt3.ggpht.com/n5DRh94eycw6xGcOKTn6LKQw...
#
# [221 rows x 12 columns]

# %%
df_channels.describe()
# Out:
#          view_count  comment_count  subscriber_count    video_count
# count  2.210000e+02          221.0      2.210000e+02     221.000000
# mean   1.493047e+09            0.0      2.641411e+06   36474.914027
# std    2.928207e+09            0.0      3.996751e+06   72141.218975
# min    7.096000e+03            0.0      2.700000e+01      20.000000
# 25%    2.814296e+07            0.0      1.520000e+05     711.000000
# 50%    2.711304e+08            0.0      9.650000e+05    3043.000000
# 75%    1.490802e+09            0.0      3.570000e+06   37819.000000
# max    1.812601e+10            0.0      2.210000e+07  610000.000000

# %% [markdown]
# ### Estatísticas

# %%
import pandas as pd

# Função para calcular a quantidade e quantidade de valores nulos
def calculate_stats(df, column):
    return {
        'unique': df[column].nunique(),
        'null_values': df[column].isnull().sum(),
        'total': df[column].count()
    }

# Função para gerar estatísticas gerais
def generate_stats(df_comments, verbose=False):
    stats = {}

    # Estatísticas sobre os canais
    stats['channels'] = calculate_stats(df_comments, 'channel_id')

    # Estatísticas sobre os vídeos
    stats['videos'] = calculate_stats(df_comments, 'video_id')

    # Estatísticas sobre os usuários que comentaram
    stats['comment_authors'] = calculate_stats(df_comments, 'author_channel_id')

    # Estatísticas sobre os comentários
    stats['comments'] = calculate_stats(df_comments, 'comment_id')

    stats = pd.DataFrame(stats).T
    if verbose:
      print(stats)
    return stats

# %%
# Função para remover duplicatas e manter os registros mais recentes.
# Intuito: garantir que não foram coletados dados repetidos para diferentes países
def remove_duplicates(df, id_column, date_column):
    # Ordena por data de forma decrescente e remove duplicatas mantendo o mais recente
    df_sorted = df.sort_values(by=date_column, ascending=False)
    df_unique = df_sorted.drop_duplicates(subset=id_column, keep='first')
    return df_unique

# %%
# Gerar as estatísticas
palestine_df_comments = remove_duplicates(palestine_df_comments, 'comment_id', 'updated_at')

# %% [markdown]
# ### Filtragem por idioma
#
# Apenas comentários em inglês serão utilizados na pesquisa. Não haverá, por agora, uma abordagem multilanguage.

# %%
# 1. Instalar FastText
# !pip install fasttext

# 2. Importar bibliotecas necessárias
import fasttext
import pandas as pd

# 3. Baixar o modelo de identificação de idiomas do FastText
# Use the raw file URL to download the binary model directly
# !wget https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.bin -O lid.176.bin
# Out:
# Requirement already satisfied: fasttext in /usr/local/lib/python3.10/dist-packages (0.9.3)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.10/dist-packages (from fasttext) (2.13.6)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (75.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.26.4)
# --2024-11-02 20:14:58--  https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.bin
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.249.39.89, 13.249.39.82, 13.249.39.25, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.249.39.89|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 131266198 (125M) [application/octet-stream]
# Saving to: ‘lid.176.bin’
#
# lid.176.bin         100%[===================>] 125.18M   153MB/s    in 0.8s
#
# 2024-11-02 20:14:59 (153 MB/s) - ‘lid.176.bin’ saved [131266198/131266198]

# %%
# Carregae o modelo de linguagem
def load_model():
    model_path = 'lid.176.bin'
    model = fasttext.load_model(model_path)
    return model

model = load_model()

# Função para identificar o idioma de um comentário
def detect_language(comment):
    # Remover quebras de linha
    if isinstance(comment, str):
      comment = comment.replace('\n', ' ').strip()  # Remove quebras de linha e espaços extras
      prediction = model.predict(comment)
      return prediction[0][0]  # Retornar o código do idioma
    else:
      return ''

def filter_by_english(df_comments, verbose=False):
  # Aplicar a função de detecção de idioma a cada comentário
  df_comments['language'] = df_comments['comment'].apply(detect_language)

  # Filtrar os comentários em inglês
  english_comments = df_comments[df_comments['language'] == '__label__en']

  if verbose:
    print(english_comments[['comment_id', 'comment']])

  return english_comments

# %%
palestine_df_comments = filter_by_english(palestine_df_comments, verbose=True)
# Out:
#                                                comment_id  \
# 789472                         UgyDIMGydtCmgB41-SN4AaABAg
# 789473                         UgxUGpdHzAceyYbIWDN4AaABAg
# 789474                         UgyPfhLChrSMH0hSopR4AaABAg
# 789475                         UgzcyIzP8x-MpOea_7V4AaABAg
# 759573  UgxUNu91s5_4wWdEJ4h4AaABAg.A8xFzWWQ0MSAAGvsgmW2l1
# ...                                                   ...
# 689599                         UgzaDFIViC98wmEqEdR4AaABAg
# 689600                         Ugw2Jtx0n6qufNR4zQJ4AaABAg
# 689601                         UgyHaEtt528FzLJe_6J4AaABAg
# 689602                         UgzrRIcuLYaO8BfdeM54AaABAg
# 689603                         UgxLKgbvmmwQxoNj3WF4AaABAg
#
#                                                   comment
# 789472  it is said that the 1948 UN resolution justifi...
# 789473  🛑the cease fire deal‼️Lebanon🟰Iran,, Syria🟰Rus...
# 789474                        As they say, “do the math!”
# 789475        Nice try B****. Palestine is a stolen land.
# 759573  @@Akna-mm5di why?just because he is telling th...
# ...                                                   ...
# 689599                    Oops. These is bad news for idf
# 689600  If you repeat a lie often enough, eventually b...
# 689601              Fools are making fool of themselves.😂
# 689602  What is the lie told by the IDF about tunnels ...
# 689603  Ohh No you mean the IDF and the Israeli govern...
#
# [727246 rows x 2 columns]

# %% [markdown]
# ### Contagem
#
# Aqui, calculamos o nosso universo a quantidade de canais, vídeos e comentários em inglês. Suas novas quantidades são calculadas, assim como o número de usuários comentaristas.

# %%
remove_duplicates(palestine_df_comments, 'comment_id', 'updated_at')
# Out:
#            video_id                                         comment_id  \
# 789472  XQGoaVvpm-c                         UgyDIMGydtCmgB41-SN4AaABAg
# 789473  XQGoaVvpm-c                         UgxUGpdHzAceyYbIWDN4AaABAg
# 789474  XQGoaVvpm-c                         UgyPfhLChrSMH0hSopR4AaABAg
# 789475  XQGoaVvpm-c                         UgzcyIzP8x-MpOea_7V4AaABAg
# 759573  rGpYoVsCTdg  UgxUNu91s5_4wWdEJ4h4AaABAg.A8xFzWWQ0MSAAGvsgmW2l1
# ...             ...                                                ...
# 689599  rvlQIo60tV4                         UgzaDFIViC98wmEqEdR4AaABAg
# 689600  rvlQIo60tV4                         Ugw2Jtx0n6qufNR4zQJ4AaABAg
# 689601  rvlQIo60tV4                         UgyHaEtt528FzLJe_6J4AaABAg
# 689602  rvlQIo60tV4                         UgzrRIcuLYaO8BfdeM54AaABAg
# 689603  rvlQIo60tV4                         UgxLKgbvmmwQxoNj3WF4AaABAg
#
#                             author  \
# 789472             @LinguaFonetica
# 789473               @dsnitzer7123
# 789474                @bravoRFId63
# 789475              @mirhaider8190
# 759573          @SonaharKhatun-o4y
# ...                            ...
# 689599    @notruthinthisworld.8414
# 689600                      @rx1-x
# 689601                  @semprince
# 689602  @franciscahammerschlag4103
# 689603         @nicholashughes8214
#
#                                  author_profile_image_url  \
# 789472  https://yt3.ggpht.com/rInZmo_JEgl4nulr_4CGI3AX...
# 789473  https://yt3.ggpht.com/ytc/AIdro_nbnAzz17y0AjU8...
# 789474  https://yt3.ggpht.com/ej1GuFl15ApadgYd_7yxo5tJ...
# 789475  https://yt3.ggpht.com/ytc/AIdro_nbh-GLc1yW_xPy...
# 759573  https://yt3.ggpht.com/ytc/AIdro_mGCcO77qRAILee...
# ...                                                   ...
# 689599  https://yt3.ggpht.com/ytc/AIdro_nGeYh4-7xWgW6D...
# 689600  https://yt3.ggpht.com/DVNqhaFcJZ-MwLeOlStzCEYn...
# 689601  https://yt3.ggpht.com/ytc/AIdro_nlK0XZCHPihWVQ...
# 689602  https://yt3.ggpht.com/ytc/AIdro_lMN55rIWAdDHgN...
# 689603  https://yt3.ggpht.com/ytc/AIdro_mAdcE4vRvBuqmF...
#
#                                        author_channel_url  \
# 789472             http://www.youtube.com/@LinguaFonetica
# 789473               http://www.youtube.com/@dsnitzer7123
# 789474                http://www.youtube.com/@bravoRFId63
# 789475              http://www.youtube.com/@mirhaider8190
# 759573          http://www.youtube.com/@SonaharKhatun-o4y
# ...                                                   ...
# 689599    http://www.youtube.com/@notruthinthisworld.8414
# 689600                      http://www.youtube.com/@rx1-x
# 689601                  http://www.youtube.com/@semprince
# 689602  http://www.youtube.com/@franciscahammerschlag4103
# 689603         http://www.youtube.com/@nicholashughes8214
#
#                author_channel_id  \
# 789472  UCAwi3tah_hWiJeJkLb2DJbw
# 789473  UCshMbwtdRAS8CnQVBoSk93w
# 789474  UChdq_Q1KPuIoN5GjvRA-Ssw
# 789475  UCxd5mGTlssjH4Vlt33wq2gw
# 759573  UCZ9loIfErRtAaXFa0ofxgNQ
# ...                          ...
# 689599  UCEzey9OLufC3Li0Q0ZmK1yQ
# 689600  UCbJOpUIYAWZmt9kD0wbuxRw
# 689601  UCAxYnY_CrgVYP5-jkRe4GqQ
# 689602  UCJ7CKcM1i6myQfVL8pY7Wkw
# 689603  UC5LRx5fEJu5grnG3UJRSL4Q
#
#                                                   comment  \
# 789472  it is said that the 1948 UN resolution justifi...
# 789473  🛑the cease fire deal‼️Lebanon🟰Iran,, Syria🟰Rus...
# 789474                        As they say, “do the math!”
# 789475        Nice try B****. Palestine is a stolen land.
# 759573  @@Akna-mm5di why?just because he is telling th...
# ...                                                   ...
# 689599                    Oops. These is bad news for idf
# 689600  If you repeat a lie often enough, eventually b...
# 689601              Fools are making fool of themselves.😂
# 689602  What is the lie told by the IDF about tunnels ...
# 689603  Ohh No you mean the IDF and the Israeli govern...
#
#                 published_at            updated_at  like_count viewer_rating  \
# 789472  2024-10-31T23:13:50Z  2024-10-31T23:13:50Z           0          none
# 789473  2024-10-31T22:28:58Z  2024-10-31T22:28:58Z           0          none
# 789474  2024-10-31T22:15:26Z  2024-10-31T22:15:26Z           0          none
# 789475  2024-10-31T22:13:54Z  2024-10-31T22:13:54Z           0          none
# 759573  2024-10-31T21:23:24Z  2024-10-31T21:23:24Z           0          none
# ...                      ...                   ...         ...           ...
# 689599  2024-09-15T05:23:58Z  2024-09-15T05:23:58Z          67          none
# 689600  2024-09-15T05:22:11Z  2024-09-15T05:22:11Z         656          none
# 689601  2024-09-15T05:21:24Z  2024-09-15T05:21:24Z         177          none
# 689602  2024-09-15T05:16:48Z  2024-09-15T05:16:48Z           4          none
# 689603  2024-09-15T05:06:35Z  2024-09-15T05:06:35Z           0          none
#
#         can_rate  is_reply                   parent_id  \
# 789472      True     False                         NaN
# 789473      True     False                         NaN
# 789474      True     False                         NaN
# 789475      True     False                         NaN
# 759573      True      True  UgxUNu91s5_4wWdEJ4h4AaABAg
# ...          ...       ...                         ...
# 689599      True     False                         NaN
# 689600      True     False                         NaN
# 689601      True     False                         NaN
# 689602      True     False                         NaN
# 689603      True     False                         NaN
#
#                       channel_id     language
# 789472  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 789473  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 789474  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 789475  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 759573  UCmTM_hPCeckqN3cPWtYZZcg  __label__en
# ...                          ...          ...
# 689599  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689600  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689601  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689602  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689603  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
#
# [727246 rows x 16 columns]

# %%
palestine_df_comments.to_csv('{country}_englishData.csv'.format(country='palestine'), index=False, encoding='utf-8')

palestine_df_comments
# Out:
#            video_id                                         comment_id  \
# 789472  XQGoaVvpm-c                         UgyDIMGydtCmgB41-SN4AaABAg
# 789473  XQGoaVvpm-c                         UgxUGpdHzAceyYbIWDN4AaABAg
# 789474  XQGoaVvpm-c                         UgyPfhLChrSMH0hSopR4AaABAg
# 789475  XQGoaVvpm-c                         UgzcyIzP8x-MpOea_7V4AaABAg
# 759573  rGpYoVsCTdg  UgxUNu91s5_4wWdEJ4h4AaABAg.A8xFzWWQ0MSAAGvsgmW2l1
# ...             ...                                                ...
# 689599  rvlQIo60tV4                         UgzaDFIViC98wmEqEdR4AaABAg
# 689600  rvlQIo60tV4                         Ugw2Jtx0n6qufNR4zQJ4AaABAg
# 689601  rvlQIo60tV4                         UgyHaEtt528FzLJe_6J4AaABAg
# 689602  rvlQIo60tV4                         UgzrRIcuLYaO8BfdeM54AaABAg
# 689603  rvlQIo60tV4                         UgxLKgbvmmwQxoNj3WF4AaABAg
#
#                             author  \
# 789472             @LinguaFonetica
# 789473               @dsnitzer7123
# 789474                @bravoRFId63
# 789475              @mirhaider8190
# 759573          @SonaharKhatun-o4y
# ...                            ...
# 689599    @notruthinthisworld.8414
# 689600                      @rx1-x
# 689601                  @semprince
# 689602  @franciscahammerschlag4103
# 689603         @nicholashughes8214
#
#                                  author_profile_image_url  \
# 789472  https://yt3.ggpht.com/rInZmo_JEgl4nulr_4CGI3AX...
# 789473  https://yt3.ggpht.com/ytc/AIdro_nbnAzz17y0AjU8...
# 789474  https://yt3.ggpht.com/ej1GuFl15ApadgYd_7yxo5tJ...
# 789475  https://yt3.ggpht.com/ytc/AIdro_nbh-GLc1yW_xPy...
# 759573  https://yt3.ggpht.com/ytc/AIdro_mGCcO77qRAILee...
# ...                                                   ...
# 689599  https://yt3.ggpht.com/ytc/AIdro_nGeYh4-7xWgW6D...
# 689600  https://yt3.ggpht.com/DVNqhaFcJZ-MwLeOlStzCEYn...
# 689601  https://yt3.ggpht.com/ytc/AIdro_nlK0XZCHPihWVQ...
# 689602  https://yt3.ggpht.com/ytc/AIdro_lMN55rIWAdDHgN...
# 689603  https://yt3.ggpht.com/ytc/AIdro_mAdcE4vRvBuqmF...
#
#                                        author_channel_url  \
# 789472             http://www.youtube.com/@LinguaFonetica
# 789473               http://www.youtube.com/@dsnitzer7123
# 789474                http://www.youtube.com/@bravoRFId63
# 789475              http://www.youtube.com/@mirhaider8190
# 759573          http://www.youtube.com/@SonaharKhatun-o4y
# ...                                                   ...
# 689599    http://www.youtube.com/@notruthinthisworld.8414
# 689600                      http://www.youtube.com/@rx1-x
# 689601                  http://www.youtube.com/@semprince
# 689602  http://www.youtube.com/@franciscahammerschlag4103
# 689603         http://www.youtube.com/@nicholashughes8214
#
#                author_channel_id  \
# 789472  UCAwi3tah_hWiJeJkLb2DJbw
# 789473  UCshMbwtdRAS8CnQVBoSk93w
# 789474  UChdq_Q1KPuIoN5GjvRA-Ssw
# 789475  UCxd5mGTlssjH4Vlt33wq2gw
# 759573  UCZ9loIfErRtAaXFa0ofxgNQ
# ...                          ...
# 689599  UCEzey9OLufC3Li0Q0ZmK1yQ
# 689600  UCbJOpUIYAWZmt9kD0wbuxRw
# 689601  UCAxYnY_CrgVYP5-jkRe4GqQ
# 689602  UCJ7CKcM1i6myQfVL8pY7Wkw
# 689603  UC5LRx5fEJu5grnG3UJRSL4Q
#
#                                                   comment  \
# 789472  it is said that the 1948 UN resolution justifi...
# 789473  🛑the cease fire deal‼️Lebanon🟰Iran,, Syria🟰Rus...
# 789474                        As they say, “do the math!”
# 789475        Nice try B****. Palestine is a stolen land.
# 759573  @@Akna-mm5di why?just because he is telling th...
# ...                                                   ...
# 689599                    Oops. These is bad news for idf
# 689600  If you repeat a lie often enough, eventually b...
# 689601              Fools are making fool of themselves.😂
# 689602  What is the lie told by the IDF about tunnels ...
# 689603  Ohh No you mean the IDF and the Israeli govern...
#
#                 published_at            updated_at  like_count viewer_rating  \
# 789472  2024-10-31T23:13:50Z  2024-10-31T23:13:50Z           0          none
# 789473  2024-10-31T22:28:58Z  2024-10-31T22:28:58Z           0          none
# 789474  2024-10-31T22:15:26Z  2024-10-31T22:15:26Z           0          none
# 789475  2024-10-31T22:13:54Z  2024-10-31T22:13:54Z           0          none
# 759573  2024-10-31T21:23:24Z  2024-10-31T21:23:24Z           0          none
# ...                      ...                   ...         ...           ...
# 689599  2024-09-15T05:23:58Z  2024-09-15T05:23:58Z          67          none
# 689600  2024-09-15T05:22:11Z  2024-09-15T05:22:11Z         656          none
# 689601  2024-09-15T05:21:24Z  2024-09-15T05:21:24Z         177          none
# 689602  2024-09-15T05:16:48Z  2024-09-15T05:16:48Z           4          none
# 689603  2024-09-15T05:06:35Z  2024-09-15T05:06:35Z           0          none
#
#         can_rate  is_reply                   parent_id  \
# 789472      True     False                         NaN
# 789473      True     False                         NaN
# 789474      True     False                         NaN
# 789475      True     False                         NaN
# 759573      True      True  UgxUNu91s5_4wWdEJ4h4AaABAg
# ...          ...       ...                         ...
# 689599      True     False                         NaN
# 689600      True     False                         NaN
# 689601      True     False                         NaN
# 689602      True     False                         NaN
# 689603      True     False                         NaN
#
#                       channel_id     language
# 789472  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 789473  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 789474  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 789475  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 759573  UCmTM_hPCeckqN3cPWtYZZcg  __label__en
# ...                          ...          ...
# 689599  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689600  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689601  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689602  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689603  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
#
# [727246 rows x 16 columns]

# %%
# Filtrar vídeos que possuem channel_id em df_channels e video_id em df_comments
df_videos_english = df_videos[
    (df_videos['video_id'].isin(palestine_df_comments['video_id']))
]

df_videos_english
# Out:
#         video_id                                              title  \
# 0    Q_7QIgSANlg  Israeli strike in Aitou in northern Lebanon ki...
# 1    bEzEBz7d1Z8  Israel Vs Hezbollah War LIVE | Inside Israel's...
# 2    tmDjav-5dUI  Israeli air strike destroys historic mosque in...
# 3    NOLJdq4zWFs  Israeli shelling of Gaza school kills at least...
# 4    gTP3ug1DBs0  Israel's brutality towards Palestinians didn’t...
# ..           ...                                                ...
# 806  rGgnRV_Hvw0  ‘Lawless world’ faced by Palestinians in the W...
# 807  a64qJkg2Ac4  Hypersonic Missile Hits Israel | US and Israel...
# 808  oVR7mgvISiA  Gaza Offensive: Israel Recruiting Asylum Seeke...
# 809  N45Kdm-Ue-U  Iran’s 3-Way Proxy War Crushes IDF; Israel Scr...
# 810  rvlQIo60tV4  IDF Shamed By Freed Hostages About Rescue Ops,...
#
#                                            description  \
# 0    The Lebanese Red Cross said 18 people were kil...
# 1    Israel Vs Hezbollah War LIVE | Inside Israel's...
# 2    Israel has destroyed an old mosque in southern...
# 3    An Israeli attack on a school used to shelter ...
# 4    The brutality Israel has been unleashing on Pa...
# ..                                                 ...
# 806  “The fact that I have an Israeli passport and ...
# 807  #Israel #Yemen #Missile #PrashantDhawan #Prash...
# 808  Israel is recruiting African asylum seekers to...
# 809  A fresh report by Israeli media outlet Haaretz...
# 810  Freed Israeli captives spill beans months afte...
#
#                    channel_id          published_at  category_id  \
# 0    UC16niRr50-MSBwiO3YDb3RA  2024-10-14T15:43:19Z           25
# 1    UCef1-8eOpJgud7szVPlZQAQ  2024-10-14T15:34:53Z           25
# 2    UCR0fZh5SBxxMNYdg0VzRFkg  2024-10-14T14:38:56Z           25
# 3    UC16niRr50-MSBwiO3YDb3RA  2024-10-14T14:34:39Z           25
# 4    UC7fWeaHhqgM4Ry-RMpM2YYw  2024-10-14T13:54:43Z           25
# ..                        ...                   ...          ...
# 806  UCR0fZh5SBxxMNYdg0VzRFkg  2024-09-15T14:32:18Z           25
# 807  UCrC8mOqJQpoB7NuIMKIS6rQ  2024-09-15T14:28:00Z           27
# 808  UC_xWTNsx7zA2uI0ydQikViA  2024-09-15T13:40:01Z           25
# 809  UCckHqySbfy5FcPP6MD_S-Yg  2024-09-15T12:10:00Z           25
# 810  UCm7lHFkt2yB_WzL67aruVBQ  2024-09-15T04:56:08Z           25
#
#                                                   tags  view_count  \
# 0    ['bbc', 'bbc news', 'news', 'world news', 'bre...        7860
# 1    ['Israel Vs Hezbollah War', 'Israel Lebanon Wa...        9347
# 2    ['middle east eye', 'mee', 'mee news', 'news',...        7805
# 3    ['bbc', 'bbc news', 'news', 'world news', 'bre...        7076
# 4    ['TRT world', 'trtworld', 'World News', 'break...        3866
# ..                                                 ...         ...
# 806  ['middle east eye', 'mee', 'mee news', 'news',...        7690
# 807  ['Gaza', 'Hamas', 'Houthi attacks on israel', ...     1871962
# 808  ['dawn news english', 'dawn news', 'dawn news ...        1003
# 809  ['times of india', 'toi', 'latest news', 'news...       21121
# 810  ['hindustan times', 'ht media', 'ht news', 'hi...      127810
#
#      like_count  comment_count  ... scheduled_end_time concurrent_viewers  \
# 0           158            113  ...                NaN                  0
# 1            66              3  ...                NaN                  0
# 2          1179            342  ...                NaN                  0
# 3           364            174  ...                NaN                  0
# 4          1391             49  ...                NaN                  0
# ..          ...            ...  ...                ...                ...
# 806         809             73  ...                NaN                  0
# 807       58048           4592  ...                NaN                  0
# 808          19              5  ...                NaN                  0
# 809         281            163  ...                NaN                  0
# 810        2320            745  ...                NaN                  0
#
#      active_live_chat_id  recording_date  \
# 0                    NaN             NaN
# 1                    NaN             NaN
# 2                    NaN             NaN
# 3                    NaN             NaN
# 4                    NaN             NaN
# ..                   ...             ...
# 806                  NaN             NaN
# 807                  NaN             NaN
# 808                  NaN             NaN
# 809                  NaN             NaN
# 810                  NaN             NaN
#
#                                        topicCategories processing_status  \
# 0    ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# 1    ['https://en.wikipedia.org/wiki/Military', 'ht...               NaN
# 2            ['https://en.wikipedia.org/wiki/Society']               NaN
# 3    ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# 4    ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# ..                                                 ...               ...
# 806  ['https://en.wikipedia.org/wiki/Politics', 'ht...               NaN
# 807          ['https://en.wikipedia.org/wiki/Society']               NaN
# 808          ['https://en.wikipedia.org/wiki/Society']               NaN
# 809  ['https://en.wikipedia.org/wiki/Military', 'ht...               NaN
# 810  ['https://en.wikipedia.org/wiki/Military', 'ht...               NaN
#
#      parts_total  parts_processed  time_left_ms processing_failure_reason
# 0              0                0             0                       NaN
# 1              0                0             0                       NaN
# 2              0                0             0                       NaN
# 3              0                0             0                       NaN
# 4              0                0             0                       NaN
# ..           ...              ...           ...                       ...
# 806            0                0             0                       NaN
# 807            0                0             0                       NaN
# 808            0                0             0                       NaN
# 809            0                0             0                       NaN
# 810            0                0             0                       NaN
#
# [806 rows x 35 columns]

# %%
df_canais_english = df_channels[
    (df_channels['channel_id'].isin(df_videos['channel_id']))
]

df_canais_english
# Out:
#                    channel_id                                     title  \
# 0    UC3asD3ORk07XRPGC47hr-0w                              GNC NEWS 360
# 1    UCkmLoDQ8AVKwEsDSJtNKmug                                 WOLD NEWS
# 2    UC1Dlsbku0-iCGc0rXgQpDHQ                            Amaizing Facts
# 3    UC3-n3-ScTQLQ_Gc2tNLJreg  Stakelbeck Tonight with Erick Stakelbeck
# 4    UCF9LFWX5cdGHBg_FDm6tFrQ                           Breezy Politics
# ..                        ...                                       ...
# 216  UCfmSignFWkk1lw4015hCyyQ                               StandWithUs
# 217  UC16niRr50-MSBwiO3YDb3RA                                  BBC News
# 218  UCHpw8xwDNhU9gdohEcJu4aA                              The Guardian
# 219  UCm7lHFkt2yB_WzL67aruVBQ                           Hindustan Times
# 220  UCupvZG-5ko_eiXAupbDfxWw                                       CNN
#
#                                            description  \
# 0    🌍 Welcome to GNC – Global News Channel! 🌍\n\nA...
# 1                                   Subscribe  for USA
# 2    Target Subscribers 1 Million\n\nHello everyone...
# 3    Welcome to the Stakelbeck Tonight with Erick S...
# 4                             Politics By The People.
# ..                                                 ...
# 216  Fighting Antisemitism and Supporting Israel Ar...
# 217  Welcome to the official BBC News YouTube chann...
# 218  The Guardian brings you news, documentaries, a...
# 219  Hindustan Times Videos bring you news, views a...
# 220  CNN is the world leader in news and informatio...
#
#                     published_at country   view_count  comment_count  \
# 0    2024-09-22T02:57:31.675741Z      US         7096              0
# 1    2024-08-31T21:48:41.363607Z      US       372583              0
# 2    2024-06-05T10:37:49.325123Z      PK     84711317              0
# 3    2024-05-03T21:23:42.240192Z      US      2423653              0
# 4    2024-02-24T18:00:09.134775Z      US    101447822              0
# ..                           ...     ...          ...            ...
# 216         2006-06-06T22:44:08Z      IL     44427727              0
# 217         2006-04-08T05:51:05Z      GB   5607586404              0
# 218         2006-02-15T03:22:40Z      GB    729761411              0
# 219         2005-11-16T02:41:16Z      IN   5607879981              0
# 220         2005-10-02T16:06:36Z     NaN  16751878276              0
#
#      subscriber_count  video_count  is_verified  \
# 0                  27           20        False
# 1                 481          275        False
# 2              238000          412        False
# 3               31300           70        False
# 4              206000          575        False
# ..                ...          ...          ...
# 216            192000         1465        False
# 217          16800000        23220        False
# 218           2290000         7250        False
# 219           7370000        69366        False
# 220          17100000       167408        False
#
#                                               keywords  \
# 0                                                  NaN
# 1                  trump noticia "kamalla harris" vote
# 2    short shorts animals viral edits israel palest...
# 3    "erick stakelbeck" "the watchman with erick st...
# 4                                                  NaN
# ..                                                 ...
# 216  standwithus Israel Education activism pro-isra...
# 217                  BBC News Official YouTube Channel
# 218  guardian news film video environment documenta...
# 219  "world news" "us news" "HT world" "Hindustan T...
# 220                CNN "CNN News" news "breaking news"
#
#                                    profile_picture_url
# 0    https://yt3.ggpht.com/rE7KFfBo-a7KVXDR2xtVoESi...
# 1    https://yt3.ggpht.com/VZXxIUrbv9NoSwomQz_4sOlC...
# 2    https://yt3.ggpht.com/dCjKkhHRFEPvorpV1vhdD1XT...
# 3    https://yt3.ggpht.com/Oz0YlzbQAiPwkqA0vH1832AL...
# 4    https://yt3.ggpht.com/I5YmN4cKN0Vaon04Qs9hBbF2...
# ..                                                 ...
# 216  https://yt3.ggpht.com/ytc/AIdro_mh8eN8fDlZehoy...
# 217  https://yt3.ggpht.com/y_esGAQOhX4rTpWvrALErAJl...
# 218  https://yt3.ggpht.com/P7QrZEnioCzOeKA2sWKyxvR5...
# 219  https://yt3.ggpht.com/rxxycwwjFXuC-eQNBcklj4P-...
# 220  https://yt3.ggpht.com/n5DRh94eycw6xGcOKTn6LKQw...
#
# [221 rows x 12 columns]

# %% [markdown]
# ## Limpeza Textual

# %%
# !pip install ftfy
# !pip install nltk
# !pip install apyori

import nltk
import csv
import re
import ftfy
from sklearn.metrics import confusion_matrix
from nltk.corpus import stopwords

import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (6.3.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy) (0.2.13)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.6)
# Requirement already satisfied: apyori in /usr/local/lib/python3.10/dist-packages (1.1.2)

# %% [markdown]
# ###Download StopWords##

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('rslp')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package rslp to /root/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ###Limpeza de Dados Textuais##

# %%
# Redução de Vocabulário
def clean_data(text):
    text = str(text)
    text = ftfy.fix_text(text)  # Corrige erros de codificação de text
    text = text.split("#")[0]
    text = text.split("https://")[0]
    text = re.sub(r'k{2,}', '', text) # Remover a sequência  de k's
    text = re.sub(r'\d+', '', text)  # Remove números
    # text = re.sub(r'@\w+\s?', '', str(text))  # Remove o padrão "@algumusuario"
    text = re.sub(r'\bRT\b', '', text, flags=re.IGNORECASE)  # Remove a sequência "RT"
    # text = re.sub(r'\s?:\s?', ' ', text)  # Remove o símbolo " : "
    # text = re.sub(r'https://\S+', '', text)  # Remove trechos que começam com "https://" seguidos por qualquer sequência de caracteres não espaços em branco
    # text = re.sub(r'http://\S+', '', text)  # Remove trechos que começam com "http://" seguidos por qualquer sequência de caracteres não espaços em branco
    text = re.sub(r'[^\w\s]|_+', '', text)  # Remove emojis
    text = re.sub(r'"', '', text)  # Remove aspas
    text = re.sub(r'[^\w\s]', '', text)  # Remove pontuação
    text = re.sub(r'mention', '', text) # Remover a palavra "mention"
    text = re.sub(r'馃', 'c', text) # Decodificar o caractere 'ç'
    text = re.sub(r'[^a-zA-Z\s]', '', text) # Manter apenas palavras no nosso alfabeto

    return text

def clean_data_and_save(df, input_dir=None, output_dir=None):
  if ( input_dir ):
    df = pd.read_csv(input_dir, encoding='utf-8')
  df['comment'] = df['comment'].apply(clean_data)
  if ( output_dir ):
    df.to_csv(output_dir, index=False, encoding='utf-8')
  return df

# %%
palestine_df_comments = clean_data_and_save(palestine_df_comments)

# %% [markdown]
# ###Remoção de StopWords##

# %%
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    if isinstance(text, str):
        filtered_text = ' '.join([word for word in text.split() if word.lower() not in stop_words])
        return filtered_text
    else:
        return text

def remove_stopword_and_save(df, input_dir=None, output_dir=None):
  if ( input_dir ): df = pd.read_csv(input_dir, encoding='utf-8')
  df['comment'] = df['comment'].apply(remove_stopwords)

  if ( output_dir ):df.to_csv(output_dir, index=False, encoding='utf-8')
  return df

# %%
palestine_df_comments = remove_stopword_and_save(palestine_df_comments)

# %% [markdown]
# ###Transformação de tweets em minúsculos e lematização##

# %%
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk import download

# Baixar dados necessários para lematização
download('wordnet')
download('omw-1.4')
download('punkt')

# Inicializar lematizador
lemmatizer = WordNetLemmatizer()

# Função para lematização
def lemmatize_text(text):
    words = text.split()  # Separar o texto em palavras
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

def preprocess_lower(text):
    if isinstance(text, str):
        tokens = nltk.word_tokenize(text.lower(), language='english')
        text = ' '.join(tokens)
        text = lemmatize_text(text)
        return text
    else:
        return text

def preprocess_lower_and_save(df, input_dir=None, output_dir=None):
  if ( input_dir ): df = pd.read_csv(input_dir, encoding='utf-8')
  df['comment'] = df['comment'].apply(preprocess_lower)

  if ( output_dir): df.to_csv(output_dir, index=False, encoding='utf-8')
  return df
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
palestine_df_comments = preprocess_lower_and_save(palestine_df_comments)

# %% [markdown]
# ### Remover Dados Duplicados

# %%
def remove_duplicates(df, id_column, date_column):
    # Ordena por data de forma decrescente e remove duplicatas mantendo o mais recente
    df_sorted = df.sort_values(by=date_column, ascending=False)
    df_unique = df_sorted.drop_duplicates(subset=id_column, keep='first')
    return df_unique

palestine_df_comments = remove_duplicates(palestine_df_comments, 'comment_id', 'published_at')

# %%
palestine_df_comments.to_csv('{bp}/{country}/{country}_finalData.csv'.format(bp=base_path, country=country), index=False, encoding='utf-8')
df_videos.to_csv('{bp}/{country}/{country}_videos.csv'.format(bp=base_path, country=country), index=False, encoding='utf-8')
df_channels.to_csv('{bp}/{country}/{country}_channels.csv'.format(bp=base_path, country=country), index=False, encoding='utf-8')

# %%
palestine_df_comments
# Out:
#            video_id                                         comment_id  \
# 789472  XQGoaVvpm-c                         UgyDIMGydtCmgB41-SN4AaABAg
# 789473  XQGoaVvpm-c                         UgxUGpdHzAceyYbIWDN4AaABAg
# 789474  XQGoaVvpm-c                         UgyPfhLChrSMH0hSopR4AaABAg
# 789475  XQGoaVvpm-c                         UgzcyIzP8x-MpOea_7V4AaABAg
# 759573  rGpYoVsCTdg  UgxUNu91s5_4wWdEJ4h4AaABAg.A8xFzWWQ0MSAAGvsgmW2l1
# ...             ...                                                ...
# 689599  rvlQIo60tV4                         UgzaDFIViC98wmEqEdR4AaABAg
# 689600  rvlQIo60tV4                         Ugw2Jtx0n6qufNR4zQJ4AaABAg
# 689601  rvlQIo60tV4                         UgyHaEtt528FzLJe_6J4AaABAg
# 689602  rvlQIo60tV4                         UgzrRIcuLYaO8BfdeM54AaABAg
# 689603  rvlQIo60tV4                         UgxLKgbvmmwQxoNj3WF4AaABAg
#
#                             author  \
# 789472             @LinguaFonetica
# 789473               @dsnitzer7123
# 789474                @bravoRFId63
# 789475              @mirhaider8190
# 759573          @SonaharKhatun-o4y
# ...                            ...
# 689599    @notruthinthisworld.8414
# 689600                      @rx1-x
# 689601                  @semprince
# 689602  @franciscahammerschlag4103
# 689603         @nicholashughes8214
#
#                                  author_profile_image_url  \
# 789472  https://yt3.ggpht.com/rInZmo_JEgl4nulr_4CGI3AX...
# 789473  https://yt3.ggpht.com/ytc/AIdro_nbnAzz17y0AjU8...
# 789474  https://yt3.ggpht.com/ej1GuFl15ApadgYd_7yxo5tJ...
# 789475  https://yt3.ggpht.com/ytc/AIdro_nbh-GLc1yW_xPy...
# 759573  https://yt3.ggpht.com/ytc/AIdro_mGCcO77qRAILee...
# ...                                                   ...
# 689599  https://yt3.ggpht.com/ytc/AIdro_nGeYh4-7xWgW6D...
# 689600  https://yt3.ggpht.com/DVNqhaFcJZ-MwLeOlStzCEYn...
# 689601  https://yt3.ggpht.com/ytc/AIdro_nlK0XZCHPihWVQ...
# 689602  https://yt3.ggpht.com/ytc/AIdro_lMN55rIWAdDHgN...
# 689603  https://yt3.ggpht.com/ytc/AIdro_mAdcE4vRvBuqmF...
#
#                                        author_channel_url  \
# 789472             http://www.youtube.com/@LinguaFonetica
# 789473               http://www.youtube.com/@dsnitzer7123
# 789474                http://www.youtube.com/@bravoRFId63
# 789475              http://www.youtube.com/@mirhaider8190
# 759573          http://www.youtube.com/@SonaharKhatun-o4y
# ...                                                   ...
# 689599    http://www.youtube.com/@notruthinthisworld.8414
# 689600                      http://www.youtube.com/@rx1-x
# 689601                  http://www.youtube.com/@semprince
# 689602  http://www.youtube.com/@franciscahammerschlag4103
# 689603         http://www.youtube.com/@nicholashughes8214
#
#                author_channel_id  \
# 789472  UCAwi3tah_hWiJeJkLb2DJbw
# 789473  UCshMbwtdRAS8CnQVBoSk93w
# 789474  UChdq_Q1KPuIoN5GjvRA-Ssw
# 789475  UCxd5mGTlssjH4Vlt33wq2gw
# 759573  UCZ9loIfErRtAaXFa0ofxgNQ
# ...                          ...
# 689599  UCEzey9OLufC3Li0Q0ZmK1yQ
# 689600  UCbJOpUIYAWZmt9kD0wbuxRw
# 689601  UCAxYnY_CrgVYP5-jkRe4GqQ
# 689602  UCJ7CKcM1i6myQfVL8pY7Wkw
# 689603  UC5LRx5fEJu5grnG3UJRSL4Q
#
#                                                   comment  \
# 789472  said un resolution justifies jewish state arab...
# 789473  cease fire deallebanoniran syriarussiaedomanyo...
# 789474                                           say math
# 789475                   nice try b palestine stolen land
# 759573  aknammdi whyjust telling truthdo humanitythe w...
# ...                                                   ...
# 689599                                  oops bad news idf
# 689600  repeat lie often enough eventually becomes israel
# 689601                                   fool making fool
# 689602  lie told idf tunnel gaza tunnel yet discovered...
# 689603  ohh mean idf israeli government lied way youll...
#
#                 published_at            updated_at  like_count viewer_rating  \
# 789472  2024-10-31T23:13:50Z  2024-10-31T23:13:50Z           0          none
# 789473  2024-10-31T22:28:58Z  2024-10-31T22:28:58Z           0          none
# 789474  2024-10-31T22:15:26Z  2024-10-31T22:15:26Z           0          none
# 789475  2024-10-31T22:13:54Z  2024-10-31T22:13:54Z           0          none
# 759573  2024-10-31T21:23:24Z  2024-10-31T21:23:24Z           0          none
# ...                      ...                   ...         ...           ...
# 689599  2024-09-15T05:23:58Z  2024-09-15T05:23:58Z          67          none
# 689600  2024-09-15T05:22:11Z  2024-09-15T05:22:11Z         656          none
# 689601  2024-09-15T05:21:24Z  2024-09-15T05:21:24Z         177          none
# 689602  2024-09-15T05:16:48Z  2024-09-15T05:16:48Z           4          none
# 689603  2024-09-15T05:06:35Z  2024-09-15T05:06:35Z           0          none
#
#         can_rate  is_reply                   parent_id  \
# 789472      True     False                         NaN
# 789473      True     False                         NaN
# 789474      True     False                         NaN
# 789475      True     False                         NaN
# 759573      True      True  UgxUNu91s5_4wWdEJ4h4AaABAg
# ...          ...       ...                         ...
# 689599      True     False                         NaN
# 689600      True     False                         NaN
# 689601      True     False                         NaN
# 689602      True     False                         NaN
# 689603      True     False                         NaN
#
#                       channel_id     language
# 789472  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 789473  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 789474  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 789475  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 759573  UCmTM_hPCeckqN3cPWtYZZcg  __label__en
# ...                          ...          ...
# 689599  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689600  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689601  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689602  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689603  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
#
# [727246 rows x 16 columns]

# %% [markdown]
# ### Remoção de linhas em branco##

# %%
def remove_empty_line_and_save(df, input_dir=None, output_dir=None):
  if ( input_dir ): pd.read_csv(input_dir, encoding='utf-8')

  df.dropna(subset=['comment'], inplace=True)
  df = df[df['comment'].str.strip() != '']

  if ( output_dir ): df.to_csv(output_dir, index=False, encoding='utf-8')
  return df

# %%
palestine_df_comments = remove_empty_line_and_save(palestine_df_comments, output_dir='{country}_finalData.csv'.format(country='palestine'))

# %%
palestine_df_comments
# Out:
#            video_id                                         comment_id  \
# 789472  XQGoaVvpm-c                         UgyDIMGydtCmgB41-SN4AaABAg
# 789473  XQGoaVvpm-c                         UgxUGpdHzAceyYbIWDN4AaABAg
# 789474  XQGoaVvpm-c                         UgyPfhLChrSMH0hSopR4AaABAg
# 789475  XQGoaVvpm-c                         UgzcyIzP8x-MpOea_7V4AaABAg
# 759573  rGpYoVsCTdg  UgxUNu91s5_4wWdEJ4h4AaABAg.A8xFzWWQ0MSAAGvsgmW2l1
# ...             ...                                                ...
# 689599  rvlQIo60tV4                         UgzaDFIViC98wmEqEdR4AaABAg
# 689600  rvlQIo60tV4                         Ugw2Jtx0n6qufNR4zQJ4AaABAg
# 689601  rvlQIo60tV4                         UgyHaEtt528FzLJe_6J4AaABAg
# 689602  rvlQIo60tV4                         UgzrRIcuLYaO8BfdeM54AaABAg
# 689603  rvlQIo60tV4                         UgxLKgbvmmwQxoNj3WF4AaABAg
#
#                             author  \
# 789472             @LinguaFonetica
# 789473               @dsnitzer7123
# 789474                @bravoRFId63
# 789475              @mirhaider8190
# 759573          @SonaharKhatun-o4y
# ...                            ...
# 689599    @notruthinthisworld.8414
# 689600                      @rx1-x
# 689601                  @semprince
# 689602  @franciscahammerschlag4103
# 689603         @nicholashughes8214
#
#                                  author_profile_image_url  \
# 789472  https://yt3.ggpht.com/rInZmo_JEgl4nulr_4CGI3AX...
# 789473  https://yt3.ggpht.com/ytc/AIdro_nbnAzz17y0AjU8...
# 789474  https://yt3.ggpht.com/ej1GuFl15ApadgYd_7yxo5tJ...
# 789475  https://yt3.ggpht.com/ytc/AIdro_nbh-GLc1yW_xPy...
# 759573  https://yt3.ggpht.com/ytc/AIdro_mGCcO77qRAILee...
# ...                                                   ...
# 689599  https://yt3.ggpht.com/ytc/AIdro_nGeYh4-7xWgW6D...
# 689600  https://yt3.ggpht.com/DVNqhaFcJZ-MwLeOlStzCEYn...
# 689601  https://yt3.ggpht.com/ytc/AIdro_nlK0XZCHPihWVQ...
# 689602  https://yt3.ggpht.com/ytc/AIdro_lMN55rIWAdDHgN...
# 689603  https://yt3.ggpht.com/ytc/AIdro_mAdcE4vRvBuqmF...
#
#                                        author_channel_url  \
# 789472             http://www.youtube.com/@LinguaFonetica
# 789473               http://www.youtube.com/@dsnitzer7123
# 789474                http://www.youtube.com/@bravoRFId63
# 789475              http://www.youtube.com/@mirhaider8190
# 759573          http://www.youtube.com/@SonaharKhatun-o4y
# ...                                                   ...
# 689599    http://www.youtube.com/@notruthinthisworld.8414
# 689600                      http://www.youtube.com/@rx1-x
# 689601                  http://www.youtube.com/@semprince
# 689602  http://www.youtube.com/@franciscahammerschlag4103
# 689603         http://www.youtube.com/@nicholashughes8214
#
#                author_channel_id  \
# 789472  UCAwi3tah_hWiJeJkLb2DJbw
# 789473  UCshMbwtdRAS8CnQVBoSk93w
# 789474  UChdq_Q1KPuIoN5GjvRA-Ssw
# 789475  UCxd5mGTlssjH4Vlt33wq2gw
# 759573  UCZ9loIfErRtAaXFa0ofxgNQ
# ...                          ...
# 689599  UCEzey9OLufC3Li0Q0ZmK1yQ
# 689600  UCbJOpUIYAWZmt9kD0wbuxRw
# 689601  UCAxYnY_CrgVYP5-jkRe4GqQ
# 689602  UCJ7CKcM1i6myQfVL8pY7Wkw
# 689603  UC5LRx5fEJu5grnG3UJRSL4Q
#
#                                                   comment  \
# 789472  said un resolution justifies jewish state arab...
# 789473  cease fire deallebanoniran syriarussiaedomanyo...
# 789474                                           say math
# 789475                   nice try b palestine stolen land
# 759573  aknammdi whyjust telling truthdo humanitythe w...
# ...                                                   ...
# 689599                                  oops bad news idf
# 689600  repeat lie often enough eventually becomes israel
# 689601                                   fool making fool
# 689602  lie told idf tunnel gaza tunnel yet discovered...
# 689603  ohh mean idf israeli government lied way youll...
#
#                 published_at            updated_at  like_count viewer_rating  \
# 789472  2024-10-31T23:13:50Z  2024-10-31T23:13:50Z           0          none
# 789473  2024-10-31T22:28:58Z  2024-10-31T22:28:58Z           0          none
# 789474  2024-10-31T22:15:26Z  2024-10-31T22:15:26Z           0          none
# 789475  2024-10-31T22:13:54Z  2024-10-31T22:13:54Z           0          none
# 759573  2024-10-31T21:23:24Z  2024-10-31T21:23:24Z           0          none
# ...                      ...                   ...         ...           ...
# 689599  2024-09-15T05:23:58Z  2024-09-15T05:23:58Z          67          none
# 689600  2024-09-15T05:22:11Z  2024-09-15T05:22:11Z         656          none
# 689601  2024-09-15T05:21:24Z  2024-09-15T05:21:24Z         177          none
# 689602  2024-09-15T05:16:48Z  2024-09-15T05:16:48Z           4          none
# 689603  2024-09-15T05:06:35Z  2024-09-15T05:06:35Z           0          none
#
#         can_rate  is_reply                   parent_id  \
# 789472      True     False                         NaN
# 789473      True     False                         NaN
# 789474      True     False                         NaN
# 789475      True     False                         NaN
# 759573      True      True  UgxUNu91s5_4wWdEJ4h4AaABAg
# ...          ...       ...                         ...
# 689599      True     False                         NaN
# 689600      True     False                         NaN
# 689601      True     False                         NaN
# 689602      True     False                         NaN
# 689603      True     False                         NaN
#
#                       channel_id     language
# 789472  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 789473  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 789474  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 789475  UC1EasxeXGzoXJb2y3HTMsLA  __label__en
# 759573  UCmTM_hPCeckqN3cPWtYZZcg  __label__en
# ...                          ...          ...
# 689599  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689600  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689601  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689602  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
# 689603  UCm7lHFkt2yB_WzL67aruVBQ  __label__en
#
# [720197 rows x 16 columns]

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def create_wordcloud(df_english):
  # Suponha que df_english seja o DataFrame que contém os comentários em inglês
  # Filtrar os comentários que têm mais de 25 caracteres
  long_comments = df_english[df_english['comment'].str.len() > 25]

  # Concatenar todos os comentários em uma única string
  text = ' '.join(long_comments['comment'].astype(str))

  # Criar a nuvem de palavras
  wordcloud = WordCloud(width=800, height=400,
                        background_color='white',
                        max_words=100,
                        colormap='viridis').generate(text)

  # Exibir a nuvem de palavras
  plt.figure(figsize=(10, 5))
  plt.imshow(wordcloud, interpolation='bilinear')
  plt.axis('off')  # Ocultar os eixos
  plt.title('WordCloud for English Data (> 25 caracters)', fontsize=16)
  plt.show()

  return wordcloud

# %%
wordcloud = create_wordcloud(palestine_df_comments)

# %% [markdown]
# ## Gráficos

# %% [markdown]
# ### Contagem de dados

# %% [markdown]
# ### Comentários por dia
